# %% [markdown]
# <center>
#     <h1 style="font-weight: bold;">
#     Binary Classification from Tabular Data
#     <br>
#     </h1>
#     <h1>
#     (amriz's version)
#     </h1>
# </center>

# %% [markdown]
# ## **Library Import**

# %%
import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from scipy.spatial.distance import cdist
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.patches as mpatches
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report

from utils.preprocessing import FeatureScaler, FeatureDimensionReducer

from IPython.display import display, HTML

from collections import Counter

from scipy.stats import zscore

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## **Data Loading**

# %%
data_path = './data/EV_data.csv'
initial_df = pd.read_csv(data_path)

# %% [markdown]
# ## **Data Understanding**

# %% [markdown]
# ### **Deskripsi Data**
#
# Memberikan gambaran umum tentang data yang akan digunakan.

# %% [markdown]
# #### **1. Memahami Struktur Data**

# %%
# Struktur Data
initial_df.head()
# Out:
#   read_date  interval_1  interval_2  interval_3  interval_4  interval_5  \
# 0  3/1/2021      0.0625      0.0500      0.0687      0.0750      0.0687
# 1  3/2/2021      0.0625      0.0500      0.0687      0.0625      0.0625
# 2  3/3/2021      0.0625      0.0687      0.0500      0.0562      0.0687
# 3  3/4/2021      0.0625      0.0625      0.0687      0.0500      0.0562
# 4  3/5/2021      0.0625      0.0625      0.0500      0.0625      0.0687
#
#    interval_6  interval_7  interval_8  interval_9  ...  interval_41  \
# 0      0.0500      0.0625      0.0687      0.0687  ...       0.0812
# 1      0.0562      0.0562      0.0625      0.0687  ...       0.1375
# 2      0.0625      0.0625      0.0625      0.0500  ...       0.1875
# 3      0.0625      0.0625      0.0625      0.0562  ...       0.1125
# 4      0.0625      0.0687      0.0562      0.0500  ...       0.0812
#
#    interval_42  interval_43  interval_44  interval_45  interval_46  \
# 0       0.0687       0.0687       0.0562       0.0562       0.0687
# 1       0.0750       0.0687       0.0625       0.0625       0.0562
# 2       0.1062       0.0750       0.0687       0.0687       0.0625
# 3       0.0875       0.0687       0.0625       0.0562       0.0625
# 4       0.0562       0.0687       0.0625       0.0625       0.0625
#
#    interval_47  interval_48  id  label
# 0       0.0687       0.0625   1      1
# 1       0.0625       0.0625   1      1
# 2       0.0562       0.0562   1      1
# 3       0.0625       0.0687   1      1
# 4       0.0562       0.0500   1      1
#
# [5 rows x 51 columns]

# %%
initial_df['read_date'].unique()
# Out:
# array(['3/1/2021', '3/2/2021', '3/3/2021', '3/4/2021', '3/5/2021',
#        '3/6/2021', '3/7/2021', '3/8/2021', '3/9/2021', '3/10/2021',
#        '3/11/2021', '3/12/2021', '3/13/2021', '3/14/2021', '3/15/2021',
#        '3/16/2021', '3/17/2021', '3/18/2021', '3/19/2021', '3/20/2021',
#        '3/21/2021', '3/22/2021', '3/23/2021', '3/24/2021', '3/25/2021',
#        '3/26/2021', '3/27/2021', '3/28/2021', '3/29/2021', '3/30/2021',
#        '3/31/2021', '4/1/2021', '4/2/2021', '4/3/2021', '4/4/2021',
#        '4/5/2021', '4/6/2021', '4/7/2021', '4/8/2021', '4/9/2021',
#        '4/10/2021', '4/11/2021', '4/12/2021', '4/13/2021', '4/14/2021',
#        '4/15/2021', '2/18/2021 0:00', '2/19/2021 0:00', '2/20/2021 0:00',
#        '2/21/2021 0:00', '2/22/2021 0:00', '2/23/2021 0:00',
#        '2/24/2021 0:00', '2/25/2021 0:00', '2/26/2021 0:00',
#        '2/27/2021 0:00', '2/28/2021 0:00', '3/1/2021 0:00',
#        '3/2/2021 0:00', '3/3/2021 0:00', '3/4/2021 0:00', '3/5/2021 0:00',
#        '3/6/2021 0:00', '3/7/2021 0:00', '3/8/2021 0:00', '3/9/2021 0:00',
#        '3/10/2021 0:00', '3/11/2021 0:00', '3/12/2021 0:00',
#        '3/13/2021 0:00', '3/14/2021 0:00', '3/15/2021 0:00',
#        '3/16/2021 0:00', '3/17/2021 0:00', '3/18/2021 0:00',
#        '3/19/2021 0:00', '3/20/2021 0:00', '3/21/2021 0:00',
#        '3/22/2021 0:00', '3/23/2021 0:00', '3/24/2021 0:00',
#        '3/25/2021 0:00', '3/26/2021 0:00', '3/27/2021 0:00',
#        '3/28/2021 0:00', '3/29/2021 0:00', '3/30/2021 0:00',
#        '3/31/2021 0:00', '4/1/2021 0:00', '4/2/2021 0:00',
#        '4/3/2021 0:00', '4/4/2021 0:00'], dtype=object)

# %%
print(f"Jumlah data: {initial_df.shape[0]}")
print(f"Jumlah kolom: {initial_df.shape[1]}")
print(initial_df.dtypes)
# Out:
# Jumlah data: 4048
# Jumlah kolom: 51
# read_date       object
# interval_1     float64
# interval_2     float64
# interval_3     float64
# interval_4     float64
# interval_5     float64
# interval_6     float64
# interval_7     float64
# interval_8     float64
# interval_9     float64
# interval_10    float64
# interval_11    float64
# interval_12    float64
# interval_13    float64
# interval_14    float64
# interval_15    float64
# interval_16    float64
# interval_17    float64
# interval_18    float64
# interval_19    float64
# interval_20    float64
# interval_21    float64
# interval_22    float64
# interval_23    float64
# interval_24    float64
# interval_25    float64
# interval_26    float64
# interval_27    float64
# interval_28    float64
# interval_29    float64
# interval_30    float64
# interval_31    float64
# interval_32    float64
# interval_33    float64
# interval_34    float64
# interval_35    float64
# interval_36    float64
# interval_37    float64
# interval_38    float64
# interval_39    float64
# interval_40    float64
# interval_41    float64
# interval_42    float64
# interval_43    float64
# interval_44    float64
# interval_45    float64
# interval_46    float64
# interval_47    float64
# interval_48    float64
# id               int64
# label            int64
# dtype: object

# %% [markdown]
# #### **2. Menentukan Variabel Target**

# %%
numerical_columns = initial_df.select_dtypes(include=[np.float64]).columns
categorical_columns = ['id']
date_columns = ['read_date']
label_column = ['label']

# %% [markdown]
# #### **3. Memeriksa Nilai Ringkasan Statistik**

# %%
# Statistik Deskriptif Numerikal
display(HTML(initial_df.describe().to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>interval_1</th>
#       <th>interval_2</th>
#       <th>interval_3</th>
#       <th>interval_4</th>
#       <th>interval_5</th>
#       <th>interval_6</th>
#       <th>interval_7</th>
#       <th>interval_8</th>
#       <th>interval_9</th>
#       <th>interval_10</th>
#       <th>interval_11</th>
#       <th>interval_12</th>
#       <th>interval_13</th>
#       <th>interval_14</th>
#       <th>interval_15</th>
#       <th>interval_16</th>
#       <th>interval_17</th>
#       <th>interval_18</th>
#       <th>interval_19</th>
#       <th>interval_20</th>
#       <th>interval_21</th>
#       <th>interval_22</th>
#       <th>interval_23</th>
#       <th>interval_24</th>
#       <th>interval_25</th>
#       <th>interval_26</th>
#       <th>interval_27</th>
#       <th>interval_28</th>
#       <th>interval_29</th>
#       <th>interval_30</th>
#       <th>interval_31</th>
#       <th>interval_32</th>
#       <th>interval_33</th>
#       <th>interval_34</th>
#       <th>interval_35</th>
#       <th>interval_36</th>
#       <th>interval_37</th>
#       <th>interval_38</th>
#       <th>interval_39</th>
#       <th>interval_40</th>
#       <th>interval_41</th>
#       <th>interval_42</th>
#       <th>interval_43</th>
#       <th>interval_44</th>
#       <th>interval_45</th>
#       <th>interval_46</th>
#       <th>interval_47</th>
#       <th>interval_48</th>
#       <th>id</th>
#       <th>label</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>4048.000000</td>
#       <td>4048.000000</td>
#       <td>4048.000000</td>
#       <td>4048.000000</td>
#       <td>4048.000000</td>
#       <td>4048.000000</td>
#       <td>4048.000000</td>
#       <td>4048.000000</td>
#       <td>4048.000000</td>
#       <td>4048.000000</td>
#       <td>4048.000000</td>
#       <td>4048.000000</td>
#       <td>4048.000000</td>
#       <td>4048.000000</td>
#       <td>4048.000000</td>
#       <td>4048.000000</td>
#       <td>4048.000000</td>
#       <td>4048.000000</td>
#       <td>4048.000000</td>
#       <td>4048.000000</td>
#       <td>4048.000000</td>
#       <td>4048.000000</td>
#       <td>4048.000000</td>
#       <td>4048.000000</td>
#       <td>4048.000000</td>
#       <td>4048.000000</td>
#       <td>4048.000000</td>
#       <td>4048.000000</td>
#       <td>4048.000000</td>
#       <td>4048.000000</td>
#       <td>4048.000000</td>
#       <td>4048.000000</td>
#       <td>4048.000000</td>
#       <td>4048.000000</td>
#       <td>4048.000000</td>
#       <td>4048.000000</td>
#       <td>4048.000000</td>
#       <td>4048.000000</td>
#       <td>4048.000000</td>
#       <td>4048.000000</td>
#       <td>4048.000000</td>
#       <td>4048.000000</td>
#       <td>4048.000000</td>
#       <td>4048.000000</td>
#       <td>4048.000000</td>
#       <td>4048.000000</td>
#       <td>4048.000000</td>
#       <td>4048.000000</td>
#       <td>4048.00000</td>
#       <td>4048.000000</td>
#     </tr>
#     <tr>
#       <th>mean</th>
#       <td>0.344301</td>
#       <td>0.320546</td>
#       <td>0.297221</td>
#       <td>0.276360</td>
#       <td>0.255266</td>
#       <td>0.244258</td>
#       <td>0.250251</td>
#       <td>0.251163</td>
#       <td>0.255017</td>
#       <td>0.230583</td>
#       <td>0.217867</td>
#       <td>0.238736</td>
#       <td>0.257309</td>
#       <td>0.295889</td>
#       <td>0.288309</td>
#       <td>0.283624</td>
#       <td>0.283028</td>
#       <td>0.272364</td>
#       <td>0.263760</td>
#       <td>0.260320</td>
#       <td>0.251750</td>
#       <td>0.251437</td>
#       <td>0.250036</td>
#       <td>0.258450</td>
#       <td>0.251384</td>
#       <td>0.261171</td>
#       <td>0.260740</td>
#       <td>0.261707</td>
#       <td>0.265499</td>
#       <td>0.275546</td>
#       <td>0.282772</td>
#       <td>0.293687</td>
#       <td>0.312935</td>
#       <td>0.340652</td>
#       <td>0.374661</td>
#       <td>0.399541</td>
#       <td>0.422568</td>
#       <td>0.432408</td>
#       <td>0.426493</td>
#       <td>0.422762</td>
#       <td>0.407895</td>
#       <td>0.402141</td>
#       <td>0.392470</td>
#       <td>0.367511</td>
#       <td>0.359634</td>
#       <td>0.341184</td>
#       <td>0.381160</td>
#       <td>0.365073</td>
#       <td>44.50000</td>
#       <td>0.500000</td>
#     </tr>
#     <tr>
#       <th>std</th>
#       <td>0.698534</td>
#       <td>0.655992</td>
#       <td>0.607303</td>
#       <td>0.554286</td>
#       <td>0.492384</td>
#       <td>0.461366</td>
#       <td>0.598976</td>
#       <td>0.606699</td>
#       <td>0.616976</td>
#       <td>0.426445</td>
#       <td>0.388668</td>
#       <td>0.342023</td>
#       <td>0.328390</td>
#       <td>0.405575</td>
#       <td>0.380756</td>
#       <td>0.400106</td>
#       <td>0.430066</td>
#       <td>0.447352</td>
#       <td>0.471054</td>
#       <td>0.461368</td>
#       <td>0.462819</td>
#       <td>0.479617</td>
#       <td>0.475716</td>
#       <td>0.482956</td>
#       <td>0.478675</td>
#       <td>0.516921</td>
#       <td>0.523557</td>
#       <td>0.516714</td>
#       <td>0.516509</td>
#       <td>0.537958</td>
#       <td>0.541808</td>
#       <td>0.537004</td>
#       <td>0.533615</td>
#       <td>0.552876</td>
#       <td>0.622922</td>
#       <td>0.627571</td>
#       <td>0.632085</td>
#       <td>0.625359</td>
#       <td>0.620732</td>
#       <td>0.629121</td>
#       <td>0.587563</td>
#       <td>0.593329</td>
#       <td>0.607965</td>
#       <td>0.577805</td>
#       <td>0.614594</td>
#       <td>0.622205</td>
#       <td>0.773924</td>
#       <td>0.745274</td>
#       <td>25.40491</td>
#       <td>0.500062</td>
#     </tr>
#     <tr>
#       <th>min</th>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>1.00000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <th>25%</th>
#       <td>0.073000</td>
#       <td>0.072000</td>
#       <td>0.070000</td>
#       <td>0.069000</td>
#       <td>0.066000</td>
#       <td>0.066000</td>
#       <td>0.064000</td>
#       <td>0.066000</td>
#       <td>0.064000</td>
#       <td>0.065000</td>
#       <td>0.068000</td>
#       <td>0.074000</td>
#       <td>0.086000</td>
#       <td>0.087500</td>
#       <td>0.075000</td>
#       <td>0.061750</td>
#       <td>0.050000</td>
#       <td>0.043000</td>
#       <td>0.031200</td>
#       <td>0.025000</td>
#       <td>0.025000</td>
#       <td>0.018925</td>
#       <td>0.018700</td>
#       <td>0.018700</td>
#       <td>0.012500</td>
#       <td>0.012500</td>
#       <td>0.012500</td>
#       <td>0.018700</td>
#       <td>0.020425</td>
#       <td>0.025000</td>
#       <td>0.035000</td>
#       <td>0.037500</td>
#       <td>0.043700</td>
#       <td>0.060000</td>
#       <td>0.072000</td>
#       <td>0.093700</td>
#       <td>0.112500</td>
#       <td>0.120000</td>
#       <td>0.127000</td>
#       <td>0.125000</td>
#       <td>0.121000</td>
#       <td>0.118700</td>
#       <td>0.113000</td>
#       <td>0.105000</td>
#       <td>0.088000</td>
#       <td>0.081200</td>
#       <td>0.077000</td>
#       <td>0.075000</td>
#       <td>22.75000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <th>50%</th>
#       <td>0.137500</td>
#       <td>0.131200</td>
#       <td>0.125000</td>
#       <td>0.125000</td>
#       <td>0.125000</td>
#       <td>0.118700</td>
#       <td>0.118700</td>
#       <

# %%
# Distribusi Frekuesi Kategorikal
sorted_df = initial_df['id'].value_counts().to_frame().sort_index()
sorted_df.columns = ['frequency']
display(HTML(sorted_df.to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>frequency</th>
#     </tr>
#     <tr>
#       <th>id</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>46</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>46</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>46</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>46</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>46</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>46</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>46</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>46</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>46</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>46</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>46</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>46</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>46</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>46</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>46</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>46</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>46</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>46</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>46</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>46</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>46</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>46</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>46</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>46</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>46</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>46</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>46</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>46</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>46</td>
#     </tr>
#     <tr>
#       <th>30</th>
#       <td>46</td>
#     </tr>
#     <tr>
#       <th>31</th>
#       <td>46</td>
#     </tr>
#     <tr>
#       <th>32</th>
#       <td>46</td>
#     </tr>
#     <tr>
#       <th>33</th>
#       <td>46</td>
#     </tr>
#     <tr>
#       <th>34</th>
#       <td>46</td>
#     </tr>
#     <tr>
#       <th>35</th>
#       <td>46</td>
#     </tr>
#     <tr>
#       <th>36</th>
#       <td>46</td>
#     </tr>
#     <tr>
#       <th>37</th>
#       <td>46</td>
#     </tr>
#     <tr>
#       <th>38</th>
#       <td>46</td>
#     </tr>
#     <tr>
#       <th>39</th>
#       <td>46</td>
#     </tr>
#     <tr>
#       <th>40</th>
#       <td>46</td>
#     </tr>
#     <tr>
#       <th>41</th>
#       <td>46</td>
#     </tr>
#     <tr>
#       <th>42</th>
#       <td>46</td>
#     </tr>
#     <tr>
#       <th>43</th>
#       <td>46</td>
#     </tr>
#     <tr>
#       <th>44</th>
#       <td>46</td>
#     </tr>
#     <tr>
#       <th>45</th>
#       <td>46</td>
#     </tr>
#     <tr>
#       <th>46</th>
#       <td>46</td>
#     </tr>
#     <tr>
#       <th>47</th>
#       <td>46</td>
#     </tr>
#     <tr>
#       <th>48</th>
#       <td>46</td>
#     </tr>
#     <tr>
#       <th>49</th>
#       <td>46</td>
#     </tr>
#     <tr>
#       <th>50</th>
#       <td>46</td>
#     </tr>
#     <tr>
#       <th>51</th>
#       <td>46</td>
#     </tr>
#     <tr>
#       <th>52</th>
#       <td>46</td>
#     </tr>
#     <tr>
#       <th>53</th>
#       <td>46</td>
#     </tr>
#     <tr>
#       <th>54</th>
#       <td>46</td>
#     </tr>
#     <tr>
#       <th>55</th>
#       <td>46</td>
#     </tr>
#     <tr>
#       <th>56</th>
#       <td>46</td>
#     </tr>
#     <tr>
#       <th>57</th>
#       <td>46</td>
#     </tr>
#     <tr>
#       <th>58</th>
#       <td>46</td>
#     </tr>
#     <tr>
#       <th>59</th>
#       <td>46</td>
#     </tr>
#     <tr>
#       <th>60</th>
#       <td>46</td>
#     </tr>
#     <tr>
#       <th>61</th>
#       <td>46</td>
#     </tr>
#     <tr>
#       <th>62</th>
#       <td>46</td>
#     </tr>
#     <tr>
#       <th>63</th>
#       <td>46</td>
#     </tr>
#     <tr>
#       <th>64</th>
#       <td>46</td>
#     </tr>
#     <tr>
#       <th>65</th>
#       <td>46</td>
#     </tr>
#     <tr>
#       <th>66</th>
#       <td>46</td>
#     </tr>
#     <tr>
#       <th>67</th>
#       <td>46</td>
#     </tr>
#     <tr>
#       <th>68</th>
#       <td>46</td>
#     </tr>
#     <tr>
#       <th>69</th>
#       <td>46</td>
#     </tr>
#     <tr>
#       <th>70</th>
#       <td>46</td>
#     </tr>
#     <tr>
#       <th>71</th>
#       <td>46</td>
#     </tr>
#     <tr>
#       <th>72</th>
#       <td>46</td>
#     </tr>
#     <tr>
#       <th>73</th>
#       <td>46</td>
#     </tr>
#     <tr>
#       <th>74</th>
#       <td>46</td>
#     </tr>
#     <tr>
#       <th>75</th>
#       <td>46</td>
#     </tr>
#     <tr>
#       <th>76</th>
#       <td>46</td>
#     </tr>
#     <tr>
#       <th>77</th>
#       <td>46</td>
#     </tr>
#     <tr>
#       <th>78</th>
#       <td>46</td>
#     </tr>
#     <tr>
#       <th>79</th>
#       <td>46</td>
#     </tr>
#     <tr>
#       <th>80</th>
#       <td>46</td>
#     </tr>
#     <tr>
#       <th>81</th>
#       <td>46</td>
#     </tr>
#     <tr>
#       <th>82</th>
#       <td>46</td>
#     </tr>
#     <tr>
#       <th>83</th>
#       <td>46</td>
#     </tr>
#     <tr>
#       <th>84</th>
#       <td>46</td>
#     </tr>
#     <tr>
#       <th>85</th>
#       <td>46</td>
#     </tr>
#     <tr>
#       <th>86</th>
#       <td>46</td>
#     </tr>
#     <tr>
#       <th>87</th>
#       <td>46</td>
#     </tr>
#     <tr>
#       <th>88</th>
#       <td>46</td>
#     </tr>
#   </tbody>
# </table>

# %%
def plot_pie_chart(df, label):
    """
    This function plots a pie chart for the class distribution in the label column
    and prints the value counts for each class in a nicely formatted way, 
    without modifying the original DataFrame.
    
    Parameters:
    df (pd.DataFrame): The dataframe containing the data.
    label (str): The column name for the label/class to be plotted.
    """
    # Replace NaN with 'NaN' for plotting only, without modifying the original df
    plot_data = df[label].fillna('NaN')

    # Get the value counts of the label
    class_counts = plot_data.value_counts()  # NaN values are replaced with 'Missing'
    total = len(plot_data)

    # Print the value counts with percentages in a more readable format
    print(f"Value Counts for '{label}':")
    for cls, count in class_counts.items():
        percentage = (count / total) * 100
        print(f"  {cls}: {count} ({percentage:.2f}%)")
    
    # Plot the pie chart
    plt.figure(figsize=(8, 6))
    plt.pie(class_counts, labels=[f'{cls} ({count})' for cls, count in class_counts.items()],
            autopct=lambda p: f'{p:.2f}%', startangle=90, colors=plt.cm.Paired.colors)
    plt.title(f"Class Distribution for '{label}'")
    plt.axis('equal')  # Ensures the pie chart is a circle
    plt.show()

# Distribusi Frekuensi Label
plot_pie_chart(initial_df, 'label')
# Out:
# Value Counts for 'label':
#   1: 2024 (50.00%)
#   0: 2024 (50.00%)

# %% [markdown]
# ### **Eksplorasi Data**
#
# Untuk memahami struktur, mengidentikasi pola, tren, dan korelasi dalam data.

# %% [markdown]
# #### **Analisa Statistik Deskriptif Lanjutan**

# %% [markdown]
# Skewness: Untuk mengetahui seberapa simetris distribusi data.

# %% [markdown]
# <!-- TODO: To Be Continued... -->
# TODO: To Be Continued...

# %% [markdown]
# ### **Verifikasi Kualitas Data**
#
# Untuk memastikan bahwa data yang digunakan bersih, konsisten, dan dapat diandalkan.

# %% [markdown]
# #### **1. Identifikasi Missing Values**

# %%
def missing_value_stats(df):
    missing_percentage = (df.isnull().sum() / len(df)) * 100

    # Create a DataFrame with missing counts and percentages
    missing_data = pd.DataFrame({
        'Missing Count': df.isnull().sum(),
        'Missing Percentage': missing_percentage.round(2).astype(str) + '%',
    })

    return missing_data

# %%
# Missing Value
missing_value_stats(initial_df)
# Out:
#              Missing Count Missing Percentage
# read_date                0               0.0%
# interval_1               0               0.0%
# interval_2               0               0.0%
# interval_3               0               0.0%
# interval_4               0               0.0%
# interval_5               0               0.0%
# interval_6               0               0.0%
# interval_7               0               0.0%
# interval_8               0               0.0%
# interval_9               0               0.0%
# interval_10              0               0.0%
# interval_11              0               0.0%
# interval_12              0               0.0%
# interval_13              0               0.0%
# interval_14              0               0.0%
# interval_15              0               0.0%
# interval_16              0               0.0%
# interval_17              0               0.0%
# interval_18              0               0.0%
# interval_19              0               0.0%
# interval_20              0               0.0%
# interval_21              0               0.0%
# interval_22              0               0.0%
# interval_23              0               0.0%
# interval_24              0               0.0%
# interval_25              0               0.0%
# interval_26              0               0.0%
# interval_27              0               0.0%
# interval_28              0               0.0%
# interval_29              0               0.0%
# interval_30              0               0.0%
# interval_31              0               0.0%
# interval_32              0               0.0%
# interval_33              0               0.0%
# interval_34              0               0.0%
# interval_35              0               0.0%
# interval_36              0               0.0%
# interval_37              0               0.0%
# interval_38              0               0.0%
# interval_39              0               0.0%
# interval_40              0               0.0%
# interval_41              0               0.0%
# interval_42              0               0.0%
# interval_43              0               0.0%
# interval_44              0               0.0%
# interval_45              0               0.0%
# interval_46              0               0.0%
# interval_47              0               0.0%
# interval_48              0               0.0%
# id                       0               0.0%
# label                    0               0.0%

# %% [markdown]
# #### **2. Identifikasi Duplikasi Data**

# %%
def duplicate_stats(df):
    # Find the duplicated rows
    duplicated_rows = df[df.duplicated()]

    # Find the duplicated columns
    duplicated_columns = df.columns[df.columns.duplicated()]

    return duplicated_rows, duplicated_columns

# %%
# Duplicate Data
duplicate_rows, duplicate_columns = duplicate_stats(initial_df)
print(f"Duplicate Rows: {len(duplicate_rows)}")
print(f"Duplicate Columns: {len(duplicate_columns)}")
# Out:
# Duplicate Rows: 0
# Duplicate Columns: 0

# %% [markdown]
# #### **3. Identikasi Konsisetensi Data**

# %%
# Check numerical columns for negative values
def check_negative_values(df, numerical_columns):
    negative_values = {}
    for col in numerical_columns:
        negative_values[col] = df[df[col] < 0].shape[0]

    return negative_values

# %%
# Check Negative Values
negative_values = check_negative_values(initial_df, numerical_columns)
print("Negative Values:")
for col, count in negative_values.items():
    print(f"  {col}: {count}")
# Out:
# Negative Values:
#   interval_1: 0
#   interval_2: 0
#   interval_3: 0
#   interval_4: 0
#   interval_5: 0
#   interval_6: 0
#   interval_7: 0
#   interval_8: 0
#   interval_9: 0
#   interval_10: 0
#   interval_11: 0
#   interval_12: 0
#   interval_13: 0
#   interval_14: 0
#   interval_15: 0
#   interval_16: 0
#   interval_17: 0
#   interval_18: 0
#   interval_19: 0
#   interval_20: 0
#   interval_21: 0
#   interval_22: 0
#   interval_23: 0
#   interval_24: 0
#   interval_25: 0
#   interval_26: 0
#   interval_27: 0
#   interval_28: 0
#   interval_29: 0
#   interval_30: 0
#   interval_31: 0
#   interval_32: 0
#   interval_33: 0
#   interval_34: 0
#   interval_35: 0
#   interval_36: 0
#   interval_37: 0
#   interval_38: 0
#   interval_39: 0
#   interval_40: 0
#   interval_41: 0
#   interval_42: 0
#   interval_43: 0
#   interval_44: 0
#   interval_45: 0
#   interval_46: 0
#   interval_47: 0
#   interval_48: 0

# %%
# Check the data if with the same id have the same label
# Group the data by 'id' and check the number of unique labels per group
label_consistency_check = initial_df.groupby('id')['label'].nunique()

# Find ids with more than one unique label
inconsistent_ids = label_consistency_check[label_consistency_check > 1]

# Display the results
if inconsistent_ids.empty:
    print("All ids have consistent labels.")
else:
    print("Inconsistent labels found for the following ids:")
    print(inconsistent_ids)
    print(f"Number of inconsistent ids: {len(inconsistent_ids)}")
# Out:
# All ids have consistent labels.

# %% [markdown]
# #### **4. Identifikasi Format Data**

# %%
# Check Unique Values for read_date
unique_dates = initial_df['read_date'].unique()
unique_dates
# Out:
# array(['3/1/2021', '3/2/2021', '3/3/2021', '3/4/2021', '3/5/2021',
#        '3/6/2021', '3/7/2021', '3/8/2021', '3/9/2021', '3/10/2021',
#        '3/11/2021', '3/12/2021', '3/13/2021', '3/14/2021', '3/15/2021',
#        '3/16/2021', '3/17/2021', '3/18/2021', '3/19/2021', '3/20/2021',
#        '3/21/2021', '3/22/2021', '3/23/2021', '3/24/2021', '3/25/2021',
#        '3/26/2021', '3/27/2021', '3/28/2021', '3/29/2021', '3/30/2021',
#        '3/31/2021', '4/1/2021', '4/2/2021', '4/3/2021', '4/4/2021',
#        '4/5/2021', '4/6/2021', '4/7/2021', '4/8/2021', '4/9/2021',
#        '4/10/2021', '4/11/2021', '4/12/2021', '4/13/2021', '4/14/2021',
#        '4/15/2021', '2/18/2021 0:00', '2/19/2021 0:00', '2/20/2021 0:00',
#        '2/21/2021 0:00', '2/22/2021 0:00', '2/23/2021 0:00',
#        '2/24/2021 0:00', '2/25/2021 0:00', '2/26/2021 0:00',
#        '2/27/2021 0:00', '2/28/2021 0:00', '3/1/2021 0:00',
#        '3/2/2021 0:00', '3/3/2021 0:00', '3/4/2021 0:00', '3/5/2021 0:00',
#        '3/6/2021 0:00', '3/7/2021 0:00', '3/8/2021 0:00', '3/9/2021 0:00',
#        '3/10/2021 0:00', '3/11/2021 0:00', '3/12/2021 0:00',
#        '3/13/2021 0:00', '3/14/2021 0:00', '3/15/2021 0:00',
#        '3/16/2021 0:00', '3/17/2021 0:00', '3/18/2021 0:00',
#        '3/19/2021 0:00', '3/20/2021 0:00', '3/21/2021 0:00',
#        '3/22/2021 0:00', '3/23/2021 0:00', '3/24/2021 0:00',
#        '3/25/2021 0:00', '3/26/2021 0:00', '3/27/2021 0:00',
#        '3/28/2021 0:00', '3/29/2021 0:00', '3/30/2021 0:00',
#        '3/31/2021 0:00', '4/1/2021 0:00', '4/2/2021 0:00',
#        '4/3/2021 0:00', '4/4/2021 0:00'], dtype=object)

# %% [markdown]
# #### **5. Identifikasi Anomali Data (Outliers)**

# %%
def plot_boxplot(data, numerical_features, title, label=None):
    """
    Fungsi untuk memplot boxplot menggunakan sns.boxplot
    Args:
    - data: DataFrame yang berisi data
    - numerical_features: Daftar nama fitur numerik yang ingin diplot
    - title: Judul dari plot

    Output:
    - Plot boxplot untuk setiap fitur numerik
    """

    if label:
        numerical_features = numerical_features.copy()
        numerical_features.append(label)

    plt.figure(figsize=(20, 40))
    
    # Looping untuk setiap fitur numerik
    for i, feature in enumerate(numerical_features, 1):
        plt.subplot(16, 3, i)  # Mengatur layout menjadi (7, 2)
        sns.boxplot(x=data[feature])
        plt.title(f'Boxplot of {feature}')
        plt.grid(True)
    
    plt.suptitle(title, fontsize=20, y=0.99)
    plt.tight_layout(rect=[0, 0, 1, 0.98])
    plt.show()

# %%
# Identifikasi Outliers Menggunakan Boxplot
plot_boxplot(initial_df, numerical_columns, 'Boxplot of Numerical Features')

# %% [markdown]
# ## **Data Preparation**

# %% [markdown]
# ### **Pemilihan Data**

# %% [markdown]
# #### **1. Record Selection**
#
# Tidak dilakukan dengan asumsi semua data yang ada akan digunakan.

# %% [markdown]
# #### **2. Feature Selection**

# %%
numerical_columns = initial_df.select_dtypes(include=[np.float64]).columns
id_columns = ['id']
date_columns = ['read_date']
label_column = ['label']

X = initial_df[numerical_columns]
y = initial_df[label_column]
id_df = initial_df[id_columns]
date_df = initial_df[date_columns]

# %% [markdown]
# ### **Perbaikan Data**

# %% [markdown]
# #### **1. Mengisi Missing Values**
#
# Tidak dilakukan sebab tidak ada missing values.

# %% [markdown]
# #### **2. Penghapusan Duplikasi Data**
# Tidak dilakukan sebab tidak ada duplikasi data.

# %% [markdown]
# #### **3. Penanganan Outliers**
# Tidak dilakukan sebab outlier dapat memberikan informasi yang berharga.

# %% [markdown]
# #### **4. Perbaikan Error**

# %%
# Memperbaiki konsistensi format date

# Buat salinan DataFrame
df_errors_handled = initial_df.copy()

# Hilangkan bagian waktu dari kolom 'read_date' jika ada
df_errors_handled['read_date'] = df_errors_handled['read_date'].str.split(' ').str[0]

# Konversikan ke format datetime
df_errors_handled['read_date'] = pd.to_datetime(df_errors_handled['read_date'], format='%m/%d/%Y', errors='coerce')

# Gunakan .normalize() untuk mengatur waktu menjadi 00:00:00
df_errors_handled['read_date'] = df_errors_handled['read_date'].dt.normalize()

# Periksa hasil akhir
print(df_errors_handled.dtypes)
# Out:
# read_date      datetime64[ns]
# interval_1            float64
# interval_2            float64
# interval_3            float64
# interval_4            float64
# interval_5            float64
# interval_6            float64
# interval_7            float64
# interval_8            float64
# interval_9            float64
# interval_10           float64
# interval_11           float64
# interval_12           float64
# interval_13           float64
# interval_14           float64
# interval_15           float64
# interval_16           float64
# interval_17           float64
# interval_18           float64
# interval_19           float64
# interval_20           float64
# interval_21           float64
# interval_22           float64
# interval_23           float64
# interval_24           float64
# interval_25           float64
# interval_26           float64
# interval_27           float64
# interval_28           float64
# interval_29           float64
# interval_30           float64
# interval_31           float64
# interval_32           float64
# interval_33           float64
# interval_34           float64
# interval_35           float64
# interval_36           float64
# interval_37           float64
# interval_38           float64
# interval_39           float64
# interval_40           float64
# interval_41           float64
# interval_42           float64
# interval_43           float64
# interval_44           float64
# interval_45           float64
# interval_46           float64
# interval_47           float64
# interval_48           float64
# id                      int64
# label                   int64
# dtype: object

# %% [markdown]
# ### **Konstruksi Data (Training Set & Testing Set)**

# %% [markdown]
# #### **1. Train-Test Split**
#
# Memisahkan data menjadi data training dan data testing, untuk mencegah leakage.

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=0, stratify=y)

print(f"Jumlah data training: {X_train.shape[0]}")
print(f"Jumlah data testing: {X_test.shape[0]}")
# Out:
# Jumlah data training: 3643
# Jumlah data testing: 405

# %% [markdown]
# #### **2. Encoding Categorical Data**
#
# Tidak dilakukan sebab data sudah dalam bentuk numerik.

# %% [markdown]
# #### **3. Feature Engineering**
#
# Menggunakan teknik feature engineering dengan melakukan clustering menggunakan 2 metode yaitu KMeans dan BIRCH.
#
# **Pipeline:** Means Grouping by id → PCA → CLustering

# %% [markdown]
# ##### **a. Means Grouping by id**

# %%
# split the id column into training and testing sets
id_train, id_test = train_test_split(id_df, test_size=0.1, random_state=0, stratify=y)

# %%
# combine X_train and X_test and id_train and id_test
X_train_with_id = pd.concat([id_train, X_train], axis=1)
X_test_with_id = pd.concat([id_test, X_test], axis=1)

# Group by id and calculate the mean for each numerical column
X_grouped_train = X_train_with_id.groupby('id').mean()
X_grouped_test = X_test_with_id.groupby('id').mean()

# Reset the index to make 'id' a column again
X_grouped_train.reset_index(inplace=True)
X_grouped_test.reset_index(inplace=True)

display(HTML(X_grouped_train.head().to_html()))
display(HTML(X_grouped_test.head().to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>interval_1</th>
#       <th>interval_2</th>
#       <th>interval_3</th>
#       <th>interval_4</th>
#       <th>interval_5</th>
#       <th>interval_6</th>
#       <th>interval_7</th>
#       <th>interval_8</th>
#       <th>interval_9</th>
#       <th>interval_10</th>
#       <th>interval_11</th>
#       <th>interval_12</th>
#       <th>interval_13</th>
#       <th>interval_14</th>
#       <th>interval_15</th>
#       <th>interval_16</th>
#       <th>interval_17</th>
#       <th>interval_18</th>
#       <th>interval_19</th>
#       <th>interval_20</th>
#       <th>interval_21</th>
#       <th>interval_22</th>
#       <th>interval_23</th>
#       <th>interval_24</th>
#       <th>interval_25</th>
#       <th>interval_26</th>
#       <th>interval_27</th>
#       <th>interval_28</th>
#       <th>interval_29</th>
#       <th>interval_30</th>
#       <th>interval_31</th>
#       <th>interval_32</th>
#       <th>interval_33</th>
#       <th>interval_34</th>
#       <th>interval_35</th>
#       <th>interval_36</th>
#       <th>interval_37</th>
#       <th>interval_38</th>
#       <th>interval_39</th>
#       <th>interval_40</th>
#       <th>interval_41</th>
#       <th>interval_42</th>
#       <th>interval_43</th>
#       <th>interval_44</th>
#       <th>interval_45</th>
#       <th>interval_46</th>
#       <th>interval_47</th>
#       <th>interval_48</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>0.392812</td>
#       <td>0.361561</td>
#       <td>0.179393</td>
#       <td>0.154246</td>
#       <td>0.154849</td>
#       <td>0.153785</td>
#       <td>0.158663</td>
#       <td>0.158971</td>
#       <td>0.157444</td>
#       <td>0.102880</td>
#       <td>0.089912</td>
#       <td>0.162320</td>
#       <td>0.198295</td>
#       <td>0.183200</td>
#       <td>0.164915</td>
#       <td>0.099068</td>
#       <td>0.100434</td>
#       <td>0.104698</td>
#       <td>0.172232</td>
#       <td>0.145722</td>
#       <td>0.156229</td>
#       <td>0.230322</td>
#       <td>0.192820</td>
#       <td>0.120415</td>
#       <td>0.049229</td>
#       <td>0.043729</td>
#       <td>0.034437</td>
#       <td>0.067512</td>
#       <td>0.066295</td>
#       <td>0.057600</td>
#       <td>0.081995</td>
#       <td>0.088244</td>
#       <td>0.114461</td>
#       <td>0.154090</td>
#       <td>0.143727</td>
#       <td>0.177873</td>
#       <td>0.171773</td>
#       <td>0.159417</td>
#       <td>0.154854</td>
#       <td>0.142205</td>
#       <td>0.328332</td>
#       <td>0.303934</td>
#       <td>0.492044</td>
#       <td>0.469488</td>
#       <td>0.463083</td>
#       <td>0.464607</td>
#       <td>0.439461</td>
#       <td>0.438383</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>0.965924</td>
#       <td>0.820697</td>
#       <td>0.732379</td>
#       <td>0.593726</td>
#       <td>0.406721</td>
#       <td>0.332545</td>
#       <td>0.234353</td>
#       <td>0.141089</td>
#       <td>0.114947</td>
#       <td>0.111326</td>
#       <td>0.122018</td>
#       <td>0.251618</td>
#       <td>0.275468</td>
#       <td>0.177282</td>
#       <td>0.194542</td>
#       <td>0.187150</td>
#       <td>0.158371</td>
#       <td>0.127453</td>
#       <td>0.105905</td>
#       <td>0.064466</td>
#       <td>0.078113</td>
#       <td>0.058047</td>
#       <td>0.099166</td>
#       <td>0.152458</td>
#       <td>0.182061</td>
#       <td>0.081571</td>
#       <td>0.074000</td>
#       <td>0.098508</td>
#       <td>0.081732</td>
#       <td>0.096697</td>
#       <td>0.148008</td>
#       <td>0.214295</td>
#       <td>0.240447</td>
#       <td>0.324984</td>
#       <td>0.362150</td>
#       <td>0.388466</td>
#       <td>0.369224</td>
#       <td>0.286326</td>
#       <td>0.263955</td>
#       <td>0.266918</td>
#       <td>0.250637</td>
#       <td>0.264447</td>
#       <td>0.268561</td>
#       <td>0.244382</td>
#       <td>0.525626</td>
#       <td>0.813621</td>
#       <td>0.899155</td>
#       <td>1.049153</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>0.584198</td>
#       <td>0.594469</td>
#       <td>0.587621</td>
#       <td>0.580629</td>
#       <td>0.538674</td>
#       <td>0.498481</td>
#       <td>0.483164</td>
#       <td>0.419474</td>
#       <td>0.342379</td>
#       <td>0.286138</td>
#       <td>0.261731</td>
#       <td>0.305633</td>
#       <td>0.536286</td>
#       <td>0.538069</td>
#       <td>0.487326</td>
#       <td>0.495210</td>
#       <td>0.634793</td>
#       <td>0.409055</td>
#       <td>0.370810</td>
#       <td>0.335838</td>
#       <td>0.352950</td>
#       <td>0.370069</td>
#       <td>0.430183</td>
#       <td>0.425429</td>
#       <td>0.410540</td>
#       <td>0.390748</td>
#       <td>0.372748</td>
#       <td>0.433305</td>
#       <td>0.415300</td>
#       <td>0.451619</td>
#       <td>0.451764</td>
#       <td>0.439412</td>
#       <td>0.417974</td>
#       <td>0.464267</td>
#       <td>0.513814</td>
#       <td>0.466636</td>
#       <td>0.498036</td>
#       <td>0.592983</td>
#       <td>0.663664</td>
#       <td>0.644619</td>
#       <td>0.723631</td>
#       <td>0.662481</td>
#       <td>0.647895</td>
#       <td>0.603102</td>
#       <td>0.634495</td>
#       <td>0.561736</td>
#       <td>0.472290</td>
#       <td>0.422295</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4</td>
#       <td>0.311192</td>
#       <td>0.348528</td>
#       <td>0.348697</td>
#       <td>0.349336</td>
#       <td>0.278979</td>
#       <td>0.255254</td>
#       <td>0.257033</td>
#       <td>0.250936</td>
#       <td>0.258310</td>
#       <td>0.254303</td>
#       <td>0.229141</td>
#       <td>0.191641</td>
#       <td>0.170005</td>
#       <td>0.179785</td>
#       <td>0.326733</td>
#       <td>0.428336</td>
#       <td>0.517605</td>
#       <td>0.655903</td>
#       <td>0.683308</td>
#       <td>0.586995</td>
#       <td>0.534910</td>
#       <td>0.452703</td>
#       <td>0.348215</td>
#       <td>0.296767</td>
#       <td>0.252697</td>
#       <td>0.193400</td>
#       <td>0.215038</td>
#       <td>0.244521</td>
#       <td>0.265359</td>
#       <td>0.221767</td>
#       <td>0.258628</td>
#       <td>0.352705</td>
#       <td>0.338751</td>
#       <td>0.385554</td>
#       <td>0.416003</td>
#       <td>0.378187</td>
#       <td>0.457026</td>
#       <td>0.476895</td>
#       <td>0.531541</td>
#       <td>0.502854</td>
#       <td>0.557182</td>
#       <td>0.719849</td>
#       <td>0.739400</td>
#       <td>0.720477</td>
#       <td>0.671610</td>
#       <td>0.497408</td>
#       <td>0.415359</td>
#       <td>0.457667</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>5</td>
#       <td>0.143392</td>
#       <td>0.145529</td>
#       <td>0.140600</td>
#       <td>0.134195</td>
#       <td>0.135832</td>
#       <td>0.136653</td>
#       <td>0.131392</td>
#       <td>0.134684</td>
#       <td>0.135668</td>
#       <td>0.127932</td>
#       <td>0.135005</td>
#       <td>0.155405</td>
#       <td>0.160505</td>
#       <td>0.139939</td>
#       <td>0.088955</td>
#       <td>0.078926</td>
#       <td>0.022682</td>
#       <td>0.031408</td>
#       <td>0.008716</td>
#       <td>0.005753</td>
#       <td>0.015295</td>
#       <td>0.005589</td>
#       <td>0.006082</td>
#       <td>0.014468</td>
#       <td>0.044071</td>
#       <td>0.059363</td>
#       <td>0.051632</td>
#       <td>0.059205</td>
#       <td>0.036834</td>
#       <td>0.040126</td>
#       <td>0.030092</td>
#       <td>0.048347</td>
#       <td>0.090782</td>
#       <td>0.117421</td>
#       <td>0.185508</td>
#       <td>0.300958</td>
#       <td>0.355568</td>
#       <td>0.382705</td>
#       <td>0.326626</td>
#       <td>0.321518</td>
#       <td>0.332866</td>
#       <td>0.325142</td>
#       <td>0.283368</td>
#       <td>0.241747</td>
#       <td>0.201126</td>
#       <td>0.193229</td>
#       <td>0.162971</td>
#       <td>0.148989</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>interval_1</th>
#       <th>interval_2</th>
#       <th>interval_3</th>
#       <th>interval_4</th>
#       <th>interval_5</th>
#       <th>interval_6</th>
#       <th>interval_7</th>
#       <th>interval_8</th>
#       <th>interval_9</th>
#       <th>interval_10</th>
#       <th>interval_11</th>
#       <th>interval_12</th>
#       <th>interval_13</th>
#       <th>interval_14</th>
#       <th>interval_15</th>
#       <th>interval_16</th>
#       <th>interval_17</th>
#       <th>interval_18</th>
#       <th>interval_19</th>
#       <th>interval_20</th>
#       <th>interval_21</th>
#       <th>interval_22</th>
#       <th>interval_23</th>
#       <th>interval_24</th>
#       <th>interval_25</th>
#       <th>interval_26</th>
#       <th>interval_27</th>
#       <th>interval_28</th>
#       <th>interval_29</th>
#       <th>interval_30</th>
#       <th>interval_31</th>
#       <th>interval_32</th>
#       <th>interval_33</th>
#       <th>interval_34</th>
#       <th>interval_35</th>
#       <th>interval_36</th>
#       <th>interval_37</th>
#       <th>interval_38</th>
#       <th>interval_39</th>
#       <th>interval_40</th>
#       <th>interval_41</th>
#       <th>interval_42</th>
#       <th>interval_43</th>
#       <th>interval_44</th>
#       <th>interval_45</th>
#       <th>interval_46</th>
#       <th>interval_47</th>
#       <th>interval_48</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>0.064980</td>
#       <td>0.059960</td>
#       <td>0.066220</td>
#       <td>0.084980</td>
#       <td>0.073740</td>
#       <td>0.059980</td>
#       <td>0.064980</td>
#       <td>0.063720</td>
#       <td>0.061220</td>
#       <td>0.057480</td>
#       <td>0.082460</td>
#       <td>0.169980</td>
#       <td>0.201220</td>
#       <td>0.107480</td>
#       <td>0.126200</td>
#       <td>0.123720</td>
#       <td>0.127480</td>
#       <td>0.058720</td>
#       <td>0.073720</td>
#       <td>0.041220</td>
#       <td>0.037480</td>
#       <td>0.182480</td>
#       <td>0.194980</td>
#       <td>0.064980</td>
#       <td>0.036220</td>
#       <td>0.028740</td>
#       <td>0.037480</td>
#       <td>0.030000</td>
#       <td>0.056240</td>
#       <td>0.037480</td>
#       <td>0.062500</td>
#       <td>0.063740</td>
#       <td>0.162480</td>
#       <td>0.233720</td>
#       <td>0.279980</td>
#       <td>0.396220</td>
#       <td>0.303720</td>
#       <td>0.303720</td>
#       <td>0.246220</td>
#       <td>0.174980</td>
#       <td>0.147480</td>
#       <td>0.089960</td>
#       <td>0.078740</td>
#       <td>0.084980</td>
#       <td>0.073720</td>
#       <td>0.064980</td>
#       <td>0.061220</td>
#       <td>0.063720</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>0.768725</td>
#       <td>0.589025</td>
#       <td>0.555438</td>
#       <td>0.555462</td>
#       <td>0.478875</td>
#       <td>0.418725</td>
#       <td>0.188262</td>
#       <td>0.087475</td>
#       <td>0.124188</td>
#       <td>0.149987</td>
#       <td>0.082787</td>
#       <td>0.167150</td>
#       <td>0.179675</td>
#       <td>0.201538</td>
#       <td>0.217938</td>
#       <td>0.066388</td>
#       <td>0.088263</td>
#       <td>0.037475</td>
#       <td>0.100775</td>
#       <td>0.028100</td>
#       <td>0.105463</td>
#       <td>0.073438</td>
#       <td>0.061713</td>
#       <td>0.028112</td>
#       <td>0.024212</td>
#       <td>0.004688</td>
#       <td>0.006237</td>
#       <td>0.012500</td>
#       <td>0.095312</td>
#       <td>0.141387</td>
#       <td>0.042175</td>
#       <td>0.091387</td>
#       <td>0.329662</td>
#       <td>0.489025</td>
#       <td>0.585125</td>
#       <td>0.534350</td>
#       <td>0.459363</td>
#       <td>0.595300</td>
#       <td>0.498425</td>
#       <td>0.469512</td>
#       <td>0.421075</td>
#       <td>0.312475</td>
#       <td>0.282788</td>
#       <td>0.297625</td>
#       <td>0.631238</td>
#       <td>0.837475</td>
#       <td>0.912475</td>
#       <td>0.751550</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>1.043725</td>
#       <td>1.042150</td>
#       <td>1.053100</td>
#       <td>1.045275</td>
#       <td>1.037475</td>
#       <td>1.032800</td>
#       <td>1.023400</td>
#       <td>1.023400</td>
#       <td>1.046825</td>
#       <td>1.042150</td>
#       <td>1.028100</td>
#       <td>0.740600</td>
#       <td>0.645275</td>
#       <td>0.518725</td>
#       <td>0.409325</td>
#       <td>0.410900</td>
#       <td>0.300000</td>
#       <td>0.240575</td>
#       <td>0.412475</td>
#       <td>0.681200</td>
#       <td>0.284350</td>
#       <td>0.274975</td>
#       <td>0.570300</td>
#       <td>0.550000</td>
#       <td>0.228100</td>
#       <td>0.259350</td>
#       <td>0.374975</td>
#       <td>0.340600</td>
#       <td>0.278100</td>
#       <td>0.531225</td>
#       <td>0.534375</td>
#       <td>0.600000</td>
#       <td>0.287450</td>
#       <td>0.189050</td>
#       <td>0.264050</td>
#       <td>0.371850</td>
#       <td>0.399975</td>
#       <td>0.229650</td>
#       <td>1.203100</td>
#       <td>1.126550</td>
#       <td>1.685900</td>
#       <td>2.157800</td>
#       <td>2.043725</td>
#       <td>2.151525</td>
#       <td>2.498425</td>
#       <td>2.468725</td>
#       <td>2.042175</td>
#       <td>1.976525</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4</td>
#       <td>0.683000</td>
#       <td>0.694614</td>
#       <td>0.675871</td>
#       <td>0.673186</td>
#       <td>0.668729</td>
#       <td>0.537457</td>
#       <td>0.141943</td>
#       <td>0.174086</td>
#       <td>0.183929</td>
#       <td>0.172286</td>
#       <td>0.157114</td>
#       <td>0.184786</td>
#       <td>0.174086</td>
#       <td>0.158900</td>
#       <td>0.158014</td>
#       <td>0.149971</td>
#       <td>0.241943</td>
#       <td>0.333029</td>
#       <td>0.353543</td>
#       <td>0.409800</td>
#       <td>0.323214</td>
#       <td>0.235686</td>
#       <td>0.226743</td>
#       <td>0.295500</td>
#       <td>0.190143</td>
#       <td>0.217843</td>
#       <td>0.266057</td>
#       <td>0.237486</td>
#       <td>0.180343</td>
#       <td>0.180329</td>
#       <td>0.156229</td>
#       <td>0.220514</td>
#       <td>0.257114</td>
#       <td>0.281214</td>
#       <td>0.272300</td>
#       <td>0.380329</td>
#       <td>0.342829</td>
#       <td>0.424986</td>
#       <td>0.542829</td>
#       <td>0.480329</td>
#       <td>0.470514</td>
#       <td>0.432129</td>
#       <td>0.416057</td>
#       <td>0.404457</td>
#       <td>0.369629</td>
#       <td>0.281214</td>
#       <td>0.195500</td>
#       <td>0.158000</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>5</td>
#       <td>0.121850</td>
#       <td>0.128087</td>
#       <td>0.137463</td>
#       <td>0.119512</td>
#       <td>0.129675</td>
#       <td>0.131225</td>
#       <td>0.122637</td>
#       <td>0.133575</td>
#       <td>0.125762</td>
#       <td>0.131225</td>
#       <td>0.129663</td>
#       <td>0.125762</td>
#       <td>0.181225</td>
#       <td>0.146863</td>
#       <td>0.075750</td>
#       <td>0.053887</td>
#       <td>0.002338</td>
#       <td>0.327325</td>
#       <td>0.444525</td>
#       <td>0.270313</td>
#       <td>0.041400</td>
#       <td>0.056250</td>
#       <td>0.021087</td>
#       <td>0.000000</td>
#       <td>0.025775</td>
#       <td>0.017175</td>
#       <td>0.003125</td>
#       <td>0.028125</td>
#       <td>0.006250</td>
#       <td>0.002338</td>
#       <td>0.002338</td>
#       <td>0.016400</td>
#       <td>0.005463</td>
#       <td>0.086700</td>
#       <td>0.077325</td>
#       <td>0.138250</td>
#       <td>0.190600</td>
#       <td>0.214825</td>
#       <td>0.251537</td>
#       <td>0.274987</td>
#       <td>0.257800</td>
#       <td>0.290600</td>
#       <td>0.272637</td>
#       <td>0.220275</td>
#       <td>0.219500</td>
#       <td>0.157000</td>
#       <td>0.166375</td>
#       <td>0.157012</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ##### **b. Principal Component Analysis (PCA) - Dimensionality Reduction**

# %%
# PCA X_grouped data with 4 components
columns_names_to_pca = X_grouped_train.columns.drop('id')
pca = FeatureDimensionReducer(method='pca', numeric_features_to_reduce=columns_names_to_pca)

X_pca_train = pca.fit_transform(X_grouped_train, threshold=0.95)
X_pca_test = pca.transform(X_grouped_test)

X_pca_train
# Out:
# Variance Ratio for each component: [5.97999596e-01 2.29374686e-01 5.61800562e-02 4.24597299e-02
#  1.90328427e-02 1.41738018e-02 7.34362283e-03 6.80132388e-03
#  5.60861552e-03 4.36988895e-03 2.98223696e-03 2.13764387e-03
#  1.78159056e-03 1.44923910e-03 1.19919846e-03 8.86602897e-04
#  7.09335243e-04 6.61618188e-04 6.29224612e-04 5.00778782e-04
#  4.59271458e-04 4.18107562e-04 3.53236952e-04 3.07149064e-04
#  2.79893613e-04 2.61313653e-04 2.50847489e-04 1.94915656e-04
#  1.67652666e-04 1.41173393e-04 1.23724508e-04 1.07277442e-04
#  9.77357179e-05 8.56564955e-05 7.71928918e-05 6.44888975e-05
#  5.96873548e-05 5.13324710e-05 3.97390997e-05 3.37309185e-05
#  3.30750709e-05 2.87092863e-05 1.86221248e-05 1.68680058e-05
#  1.54697131e-05 1.25170021e-05 1.10133159e-05 7.96593394e-06]
# Cumulative Variance Ratio: [0.5979996  0.82737428 0.88355434 0.92601407 0.94504691 0.95922071
#  0.96656434 0.97336566 0.97897427 0.98334416 0.9863264  0.98846404
#  0.99024563 0.99169487 0.99289407 0.99378068 0.99449001 0.99515163
#  0.99578085 0.99628163 0.9967409  0.99715901 0.99751225 0.9978194
#  0.99809929 0.9983606  0.99861145 0.99880637 0.99897402 0.99911519
#  0.99923892 0.9993462  0.99944393 0.99952959 0.99960678 0.99967127
#  0.99973096 0.99978229 0.99982203 0.99985576 0.99988883 0.99991754
#  0.99993617 0.99995303 0.9999685  0.99998102 0.99999203 1.        ]
# Selected number of components (threshold=95.0%): 6
#     id  component_1  component_2  component_3  component_4  component_5  \
# 0    1    -0.803264     0.435725    -0.071188     0.066271     0.331311
# 1    2    -0.070587     1.480572    -0.328994    -0.196996    -0.065874
# 2    3     1.214502     0.163576     0.112634     0.121882     0.168127
# 3    4     0.616512    -0.075902    -0.154446     0.330629     0.432833
# 4    5    -1.178961     0.087659     0.131939     0.274622    -0.111103
# ..  ..          ...          ...          ...          ...          ...
# 83  84    -0.545998    -0.392862    -0.121194     0.084257     0.029917
# 84  85    -0.895901    -0.599072    -0.292079    -0.371008    -0.302637
# 85  86     1.611186    -0.117840     0.353985    -0.290498    -0.014312
# 86  87     0.087980    -0.243163    -0.078609    -0.007348     0.136554
# 87  88    -0.608316    -0.595110    -0.129317    -0.578196     0.106496
#
#     component_6
# 0     -0.278895
# 1      0.026944
# 2      0.170285
# 3     -0.203359
# 4     -0.010401
# ..          ...
# 83    -0.002204
# 84    -0.139829
# 85     0.002938
# 86    -0.045367
# 87     0.155377
#
# [88 rows x 7 columns]

# %% [markdown]
# ##### **c. Clustering**

# %% [markdown]
# **Find Elbow**

# %%
class KMeans:
    def __init__(self, K=3, max_iters=100, random_state=42):
        self.K = K
        self.max_iters = max_iters
        self.random_state = random_state

        # List untuk menyimpan indeks sampel pada tiap cluster
        self.clusters = [[] for _ in range(self.K)]

        # List untuk menyimpan centroid (mean) dari tiap cluster
        self.centroids = []

    def fit(self, X):
        """
        Fit the KMeans model to the data.
        Parameters:
        - X: np.ndarray
            The input data to cluster.
        """
        self.X = X
        self.n_samples, self.n_features = X.shape
        
        if self.random_state is not None:
            np.random.seed(self.random_state)

        # init centroid secara acak dari sampel dalam dataset
        random_sample_idxs = np.random.choice(self.n_samples, self.K, replace=False)
        self.centroids = [self.X[idx] for idx in random_sample_idxs]

        # optimize clusters
        for _ in range(self.max_iters):
            # assign samples ke centroid terdekat
            self.clusters = self._create_clusters(self.centroids)

            # hitung centroid baru berdasarkan cluster
            centroids_old = self.centroids
            self.centroids = self._get_centroids(self.clusters)

            # Periksa konvergensi (apakah centroid tidak berubah)
            if self._is_converged(centroids_old, self.centroids):
                break

    def predict(self, X):
        """
        Predict the closest cluster each sample in X belongs to.
        Parameters:
        - X: np.ndarray
            The input data to predict.
        Returns:
        - labels: np.ndarray
            Cluster labels for each sample in X.
        """
        labels = np.empty(X.shape[0])

        for idx, sample in enumerate(X):
            distances = [self.euclidean_distance(sample, centroid) for centroid in self.centroids]
            labels[idx] = np.argmin(distances)

        return labels.astype(int)

    def fit_predict(self, X):
        """
        Fit the KMeans model and return cluster labels.
        Parameters:
        - X: np.ndarray
            The input data to cluster.
        Returns:
        - labels: np.ndarray
            Cluster labels for each sample in X.
        """
        self.fit(X)
        return self.predict(X)

    # Fungsi untuk menghitung jarak euclidean
    def euclidean_distance(self, x1, x2):
        return np.sqrt(np.sum((x1 - x2) ** 2))

    # Mendapatkan label cluster untuk tiap sampel berdasarkan assignment cluster.
    def _get_cluster_labels(self, clusters):
        labels = np.empty(self.n_samples)
        for cluster_idx, cluster in enumerate(clusters):
            for sample_idx in cluster:
                labels[sample_idx] = cluster_idx
        return labels

    # Membuat cluster dengan mengassign sampel ke centroid terdekat.
    def _create_clusters(self, centroids):
        clusters = [[] for _ in range(self.K)]
        for idx, sample in enumerate(self.X):
            centroid_idx = self._closest_centroid(sample, centroids)
            clusters[centroid_idx].append(idx)
        return clusters

    # Menentukan centroid terdekat untuk sebuah sampel.
    def _closest_centroid(self, sample, centroids):
        distances = [self.euclidean_distance(sample, point) for point in centroids]
        closest_idx = np.argmin(distances)
        return closest_idx

    # Mendapatkan centroid baru berdasarkan rata-rata nilai sampel dalam cluster.
    def _get_centroids(self, clusters):
        centroids = np.zeros((self.K, self.n_features))
        for cluster_idx, cluster in enumerate(clusters):
            cluster_mean = np.mean(self.X[cluster], axis=0)
            centroids[cluster_idx] = cluster_mean
        return centroids

    # Periksa konvergensi dengan membandingkan centroid baru dan centroid lama.
    def _is_converged(self, centroids_old, centroids):
        distances = [self.euclidean_distance(centroids_old[i], centroids[i]) for i in range(self.K)]
        return sum(distances) == 0

# %%
def find_optimal_k(sse_values):
    """
    Find the optimal k using the elbow method by identifying the point of maximum curvature
    """
    # Calculate the differences and rate of change
    differences = np.diff(sse_values)
    differences_rate = np.diff(differences)
    
    # Find the elbow point (point of maximum curvature)
    elbow_index = np.argmax(np.abs(differences_rate)) + 2
    return elbow_index

def elbow_method(df, max_k=10):
    """
    Perform elbow method analysis and visualize results with optimal k highlighted.
    """
    # Standardize the features
    scaler = MinMaxScaler()
    scaled_features = scaler.fit_transform(df)
    
    # Calculate SSE for different values of k
    sse = []
    K = range(1, max_k + 1)
    
    for k in K:
        kmeans = KMeans(K=k, max_iters=100, random_state=42)
        
        # Use fit instead of predict to ensure centroids are initialized
        kmeans.fit(scaled_features)
        
        # Calculate SSE
        current_sse = 0
        for i, cluster in enumerate(kmeans.clusters):
            if len(cluster) > 0:  # Check if cluster is not empty
                cluster_points = scaled_features[cluster]
                centroid = kmeans.centroids[i]
                current_sse += np.sum((cluster_points - centroid) ** 2)
        
        sse.append(current_sse)
    
    # Find optimal k
    optimal_k = find_optimal_k(sse)
    
    # Create the visualization
    plt.figure(figsize=(12, 7))
    
    # Plot the elbow curve
    plt.plot(K, sse, 'bo-', linewidth=2, markersize=8, label='SSE curve')
    
    # Add vertical line at optimal k
    plt.axvline(x=optimal_k, color='red', linestyle='--', 
                label=f'Optimal k = {optimal_k}')
    
    # Highlight the optimal point
    plt.plot(optimal_k, sse[optimal_k - 1], 'ro', markersize=12)
    
    # Customize the plot
    plt.xlabel('Number of Clusters (k)', fontsize=12)
    plt.ylabel('Sum of Squared Errors (SSE)', fontsize=12)
    plt.title('Elbow Method Analysis with Optimal k', fontsize=14)
    plt.grid(True, linestyle='--', alpha=0.7)
    plt.legend(fontsize=10)
    
    # Add text annotation for optimal k
    plt.annotate(f'Optimal k = {optimal_k}',
                 xy=(optimal_k, sse[optimal_k - 1]),
                 xytext=(optimal_k + 0.5, sse[optimal_k - 1]),
                 fontsize=10,
                 arrowprops=dict(facecolor='black', shrink=0.05))
    
    plt.tight_layout()
    plt.show()
    
    return sse, optimal_k


def analyze_clusters(df, optimal_k):
    """
    Perform clustering with the optimal k and return labeled data
    """
    # Standardize the features
    scaler = MinMaxScaler()
    scaled_features = scaler.fit_transform(df)
    
    # Initialize and fit KMeans model
    kmeans = KMeans(K=optimal_k, max_iters=100, random_state=42)
    kmeans.fit(scaled_features)
    
    # Predict cluster labels
    labels = kmeans.predict(scaled_features)
    
    # Return cluster labels and centroids
    return labels, kmeans.centroids

# %%
# find optimal k with df_pca_train without id columns
sse_values, optimal_k = elbow_method(X_pca_train.drop(columns=['id']), max_k=10)

# Analyze clusters with the optimal k
labels, centroids = analyze_clusters(X_pca_train.drop(columns=['id']), optimal_k)

# %%
# apply KMeans to X_pca_train and X_pca_test

# normalize the data before applying KMeans
scaler = MinMaxScaler()
X_pca_train_no_id = X_pca_train.drop(columns=['id']).values
X_pca_train_no_id_normalized = scaler.fit_transform(X_pca_train_no_id)

X_pca_test_no_id = X_pca_test.drop(columns=['id']).values
X_pca_test_no_id_normalized = scaler.transform(X_pca_test_no_id)

# Apply KMeans to X_pca_train
kmeans_train = KMeans(K=optimal_k, max_iters=100, random_state=0)

# Fit and predict labels for training data
train_labels = kmeans_train.fit_predict(X_pca_train_no_id_normalized)

# Add cluster labels back to the training DataFrame
X_pca_train_clustered = X_pca_train.copy()
X_pca_train_clustered['cluster_label'] = train_labels

# Apply KMeans to X_pca_test
test_labels = kmeans_train.predict(X_pca_test_no_id_normalized)

# Add cluster labels back to the testing DataFrame
X_pca_test_clustered = X_pca_test.copy()
X_pca_test_clustered['cluster_label'] = test_labels

# Display the updated DataFrames
display(HTML(X_pca_train_clustered.head().to_html()))
display(HTML(X_pca_test_clustered.head().to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>component_1</th>
#       <th>component_2</th>
#       <th>component_3</th>
#       <th>component_4</th>
#       <th>component_5</th>
#       <th>component_6</th>
#       <th>cluster_label</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>-0.803264</td>
#       <td>0.435725</td>
#       <td>-0.071188</td>
#       <td>0.066271</td>
#       <td>0.331311</td>
#       <td>-0.278895</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>-0.070587</td>
#       <td>1.480572</td>
#       <td>-0.328994</td>
#       <td>-0.196996</td>
#       <td>-0.065874</td>
#       <td>0.026944</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>1.214502</td>
#       <td>0.163576</td>
#       <td>0.112634</td>
#       <td>0.121882</td>
#       <td>0.168127</td>
#       <td>0.170285</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4</td>
#       <td>0.616512</td>
#       <td>-0.075902</td>
#       <td>-0.154446</td>
#       <td>0.330629</td>
#       <td>0.432833</td>
#       <td>-0.203359</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>5</td>
#       <td>-1.178961</td>
#       <td>0.087659</td>
#       <td>0.131939</td>
#       <td>0.274622</td>
#       <td>-0.111103</td>
#       <td>-0.010401</td>
#       <td>4</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>component_1</th>
#       <th>component_2</th>
#       <th>component_3</th>
#       <th>component_4</th>
#       <th>component_5</th>
#       <th>component_6</th>
#       <th>cluster_label</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>-1.347754</td>
#       <td>-0.233706</td>
#       <td>-0.026989</td>
#       <td>-0.050635</td>
#       <td>-0.164125</td>
#       <td>0.158928</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>-0.078586</td>
#       <td>1.230890</td>
#       <td>-0.234057</td>
#       <td>0.360507</td>
#       <td>-0.317658</td>
#       <td>0.090498</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>3.775210</td>
#       <td>2.696919</td>
#       <td>0.858920</td>
#       <td>1.771538</td>
#       <td>1.345780</td>
#       <td>-1.479880</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4</td>
#       <td>0.093966</td>
#       <td>0.416977</td>
#       <td>-0.099729</td>
#       <td>-0.118007</td>
#       <td>-0.092776</td>
#       <td>0.105860</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>5</td>
#       <td>-1.233360</td>
#       <td>0.026045</td>
#       <td>0.075080</td>
#       <td>0.054438</td>
#       <td>0.202676</td>
#       <td>-0.084488</td>
#       <td>4</td>
#     </tr>
#   </tbody>
# </table>

# %%
def visualize_clusters(df, labels=None, centroids=None, title="Cluster Visualization", dimensions=2):
    """
    Visualizes the dataset with clusters before or after KMeans clustering.
    
    Parameters:
    - df (pd.DataFrame): The DataFrame containing the data (PCA-reduced features).
    - labels (np.ndarray, optional): The cluster labels for each data point. Default is None.
    - centroids (np.ndarray, optional): The centroids of the clusters. Default is None.
    - title (str): The title of the plot. Default is "Cluster Visualization".
    - dimensions (int): Whether to plot in 2D or 3D (choose 2 or 3). Default is 2.
    
    Returns:
    - None. Displays a scatter plot (2D or 3D based on input dimensions).
    """
    cluster_patches = []  # For legend
    
    # Use a vibrant colormap for clusters
    colormap = plt.cm.get_cmap('tab20', len(np.unique(labels)) if labels is not None else 20)
    
    if dimensions == 3 and df.shape[1] >= 3:
        # 3D Visualization
        fig = plt.figure(figsize=(12, 8))
        ax = fig.add_subplot(111, projection='3d')
        
        if labels is not None:
            # Color points by cluster label and create patches for legend
            scatter = ax.scatter(df.iloc[:, 0], df.iloc[:, 1], df.iloc[:, 2],
                                 c=labels, cmap=colormap, s=100, alpha=0.9, edgecolors='k')
            
            unique_labels = np.unique(labels)
            for i, label in enumerate(unique_labels):
                cluster_patches.append(mpatches.Patch(color=colormap(i), 
                                                      label=f'Cluster {label}'))
        else:
            # Scatter without labels
            scatter = ax.scatter(df.iloc[:, 0], df.iloc[:, 1], df.iloc[:, 2],
                                 color='gray', s=100, alpha=0.8, edgecolors='k')
        
        if centroids is not None:
            # Plot centroids
            ax.scatter(centroids[:, 0], centroids[:, 1], centroids[:, 2],
                       s=400, c='red', marker='X', edgecolors='k', label='Centroids')
            cluster_patches.append(mpatches.Patch(color='red', label='Centroids'))
        
        # Add labels and title
        ax.set_title(title, fontsize=16, fontweight='bold')
        ax.set_xlabel("Principal Component 1", fontsize=12, fontweight='bold')
        ax.set_ylabel("Principal Component 2", fontsize=12, fontweight='bold')
        ax.set_zlabel("Principal Component 3", fontsize=12, fontweight='bold')
        ax.legend(handles=cluster_patches, loc='best', fontsize=10)
        plt.show()
    
    else:
        # 2D Visualization
        plt.figure(figsize=(12, 9))
        
        if labels is not None:
            # Color points by cluster label and create patches for legend
            scatter = plt.scatter(df.iloc[:, 0], df.iloc[:, 1], c=labels, cmap=colormap, 
                                  s=100, alpha=0.9, edgecolors='k')
            
            unique_labels = np.unique(labels)
            for i, label in enumerate(unique_labels):
                cluster_patches.append(mpatches.Patch(color=colormap(i), 
                                                      label=f'Cluster {label}'))
        else:
            # Scatter without labels
            plt.scatter(df.iloc[:, 0], df.iloc[:, 1], color='gray', s=100, alpha=0.8, edgecolors='k')
        
        if centroids is not None:
            # Plot centroids
            plt.scatter(centroids[:, 0], centroids[:, 1], s=400, c='red', marker='X', 
                        edgecolors='k', label='Centroids')
            cluster_patches.append(mpatches.Patch(color='red', label='Centroids'))
        
        # Add labels and title
        plt.title(title, fontsize=16, fontweight='bold')
        plt.xlabel("Principal Component 1", fontsize=12, fontweight='bold')
        plt.ylabel("Principal Component 2", fontsize=12, fontweight='bold')
        plt.legend(handles=cluster_patches, loc='best', fontsize=10)
        plt.grid(True, linestyle='--', alpha=0.8)
        plt.show()

# %%
# Visualize raw PCA-reduced data
visualize_clusters(X_pca_train_clustered.drop(columns=['id']), title="PCA Data Before Clustering", dimensions=3)

# Visualize clusters with labels and centroids
visualize_clusters(X_pca_train_clustered.drop(columns=['id']), 
                   labels=X_pca_train_clustered['cluster_label'].values,
                   centroids=centroids,
                   title="3D Cluster Visualization",
                   dimensions=3)

# %%
# combine the cluster labels of each id to X_train_with_id and X_train_with_id

# Prepare the cluster labels
train_clusters = X_pca_train_clustered[['id', 'cluster_label']]
test_clusters = X_pca_test_clustered[['id', 'cluster_label']]

# Left join to ensure all ids from X_train_with_id and X_test_with_id are retained
X_train_with_clusters = pd.merge(X_train_with_id, train_clusters, on='id', how='left').drop(columns=['id'])
X_test_with_clusters = pd.merge(X_test_with_id, test_clusters, on='id', how='left').drop(columns=['id'])

X_train_with_clusters.head()
# Out:
#    interval_1  interval_2  interval_3  interval_4  interval_5  interval_6  \
# 0      1.0375      1.0375      0.7937      0.0625      0.0562      0.0625
# 1      0.0312      0.1000      0.0375      0.0687      0.0625      0.0625
# 2      0.0990      0.0730      0.1300      0.1550      0.1290      0.1040
# 3      0.2670      0.1170      0.0840      0.0960      0.1090      0.0720
# 4      0.1937      0.1687      0.1687      0.1125      0.1125      0.1187
#
#    interval_7  interval_8  interval_9  interval_10  ...  interval_40  \
# 0      0.0562      0.0562      0.0625       0.0562  ...       1.0312
# 1      0.0562      0.0625      0.1375       0.1062  ...       0.1937
# 2      0.1090      0.1220      0.1000       0.0960  ...       0.2310
# 3      0.0970      0.0880      0.0830       0.0990  ...       1.5150
# 4      0.1062      0.1125      0.1000       0.0937  ...       0.8750
#
#    interval_41  interval_42  interval_43  interval_44  interval_45  \
# 0       1.0062       1.0437       1.0187        1.025       1.0375
# 1       0.1562       0.3750       0.1500        0.100       0.0625
# 2       0.1290       0.1090       0.1570        0.111       0.0950
# 3       1.3710       0.1210       0.0970        0.105       0.0840
# 4       0.2625       0.2062       0.2500        0.125       0.2812
#
#    interval_46  interval_47  interval_48  cluster_label
# 0       1.0250       1.0375       1.0187              1
# 1       0.0500       0.0562       0.0625              4
# 2       0.1350       0.1250       0.0920              4
# 3       0.1030       0.0950       0.0900              0
# 4       0.4062       0.3125       0.3000              0
#
# [5 rows x 49 columns]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

def analyze_cluster_characteristics(df, feature_columns, cluster_col='cluster_label'):
    """
    Analyze characteristics for each cluster with formatted output
    
    Parameters:
    -----------
    df : pandas DataFrame
        DataFrame containing features and cluster assignments
    feature_columns : list
        List of feature column names to analyze
    cluster_col : str
        Name of the cluster column
    """
    # Calculate size of each cluster
    cluster_sizes = df[cluster_col].value_counts().sort_index()
    cluster_percentages = (cluster_sizes / len(df) * 100).round(2)
    
    # Create a dictionary to store cluster statistics
    cluster_summaries = {}
    
    # Calculate statistics for each cluster separately
    for cluster in sorted(df[cluster_col].unique()):
        cluster_data = df[df[cluster_col] == cluster][feature_columns]
        
        print(f"\nCluster {cluster}: ")
        print(f"Size: {cluster_sizes[cluster]} samples ({cluster_percentages[cluster]}%)")
        print("mean =")
        print(cluster_data.mean().round(2))
        print("\nmin =")
        print(cluster_data.min().round(2))
        print("\nmax =")
        print(cluster_data.max().round(2))
        print("\nmedian =")
        print(cluster_data.median().round(2))
        print("\nstd =")
        print(cluster_data.std().round(2))
        print("-" * 50)
        
        # Store statistics in dictionary if needed for later use
        cluster_summaries[cluster] = {
            'mean': cluster_data.mean(),
            'min': cluster_data.min(),
            'max': cluster_data.max(),
            'median': cluster_data.median(),
            'std': cluster_data.std()
        }
    
    return cluster_summaries

def plot_feature_distributions(df, feature_columns, cluster_col='cluster_label'):
    n_features = len(feature_columns)
    fig, axes = plt.subplots(n_features, 1, figsize=(12, 5*n_features))
    
    if n_features == 1:
        axes = [axes]
    
    for ax, feature in zip(axes, feature_columns):
        sns.boxplot(data=df, x=cluster_col, y=feature, ax=ax)
        ax.set_title(f'Distribution of {feature} across clusters')
        ax.grid(True, linestyle='--', alpha=0.7)
    
    plt.tight_layout()
    plt.show()

def plot_feature_importance(df, feature_columns, cluster_col='cluster_label'):
    # Calculate mean values for each feature in each cluster
    cluster_means = df.groupby(cluster_col)[feature_columns].mean()
    
    # Calculate global means
    global_means = df[feature_columns].mean()
    
    # Calculate relative differences from global mean
    relative_importance = (cluster_means - global_means) / global_means * 100
    
    plt.figure(figsize=(24, 16))
    sns.heatmap(relative_importance, 
                annot=True, 
                fmt='.1f', 
                cmap='RdYlBu_r',
                center=0,
                cbar_kws={'label': 'Relative difference from global mean (%)'})
    plt.title('Feature Importance by Cluster')
    plt.ylabel('Cluster')
    plt.xlabel('Features')
    plt.tight_layout()
    plt.show()

def get_cluster_profiles(df, feature_columns, cluster_col='cluster_label', n_top_features=3):
    cluster_means = df.groupby(cluster_col)[feature_columns].mean()
    global_means = df[feature_columns].mean()
    relative_diff = (cluster_means - global_means) / global_means * 100
    
    profiles = {}
    for cluster in df[cluster_col].unique():
        # Get top distinguishing features
        cluster_diff = relative_diff.loc[cluster].sort_values(ascending=False)
        top_high = cluster_diff.head(n_top_features)
        top_low = cluster_diff.tail(n_top_features)
        
        profile = f"Cluster {cluster} Profile:\n"
        profile += f"Size: {len(df[df[cluster_col] == cluster])} samples\n"
        profile += "Distinguished by (percentage above average):\n"
        
        # Add high features
        profile += "Highest by consumption:\n"
        for feat, diff in top_high.items():
            profile += f"- {feat}: {diff:.1f}%\n"
        
        # Add low features
        profile += "\nLowest by consumption:\n"
        for feat, diff in top_low.items():
            profile += f"- {feat}: {diff:.1f}%\n"
            
        profiles[cluster] = profile
    
    return profiles

# %%
# Asumsikan kita memiliki feature_columns yang berisi nama-nama kolom fitur
feature_columns = [col for col in X_train_with_clusters.columns if col not in ['cluster', 'read_date', 'id', 'label']]

# 1. Analisis statistik dasar
cluster_stats = analyze_cluster_characteristics(X_train_with_clusters, feature_columns)
print("\nStatistik detail per cluster:")
print(cluster_stats)

# # 2. Visualisasi distribusi fitur
# plot_feature_distributions(merged_df, feature_columns)

# 3. Visualisasi pentingnya fitur
plot_feature_importance(X_train_with_clusters, feature_columns)

# 4. Dapatkan profil detail setiap cluster
cluster_profiles = get_cluster_profiles(X_train_with_clusters, feature_columns)
for cluster, profile in cluster_profiles.items():
    print("\n" + profile)
# Out:
# Cluster 0:
# Size: 718 samples (19.71%)
# mean =
# interval_1       0.48
# interval_2       0.43
# interval_3       0.40
# interval_4       0.37
# interval_5       0.37
# interval_6       0.37
# interval_7       0.40
# interval_8       0.40
# interval_9       0.43
# interval_10      0.38
# interval_11      0.35
# interval_12      0.36
# interval_13      0.44
# interval_14      0.55
# interval_15      0.50
# interval_16      0.57
# interval_17      0.60
# interval_18      0.57
# interval_19      0.55
# interval_20      0.53
# interval_21      0.50
# interval_22      0.49
# interval_23      0.49
# interval_24      0.52
# interval_25      0.49
# interval_26      0.50
# interval_27      0.48
# interval_28      0.46
# interval_29      0.44
# interval_30      0.45
# interval_31      0.45
# interval_32      0.48
# interval_33      0.52
# interval_34      0.55
# interval_35      0.59
# interval_36      0.64
# interval_37      0.70
# interval_38      0.75
# interval_39      0.74
# interval_40      0.76
# interval_41      0.75
# interval_42      0.77
# interval_43      0.76
# interval_44      0.71
# interval_45      0.65
# interval_46      0.61
# interval_47      0.57
# interval_48      0.52
# cluster_label    0.00
# dtype: float64
#
# min =
# interval_1       0.04
# interval_2       0.03
# interval_3       0.01
# interval_4       0.01
# interval_5       0.01
# interval_6       0.01
# interval_7       0.01
# interval_8       0.01
# interval_9       0.01
# interval_10      0.04
# interval_11      0.04
# interval_12      0.04
# interval_13      0.04
# interval_14      0.04
# interval_15      0.01
# interval_16      0.00
# interval_17      0.00
# interval_18      0.00
# interval_19      0.00
# interval_20      0.00
# interval_21      0.00
# interval_22      0.00
# interval_23      0.00
# interval_24      0.00
# interval_25      0.00
# interval_26      0.00
# interval_27      0.00
# interval_28      0.00
# interval_29      0.00
# interval_30      0.00
# interval_31      0.00
# interval_32      0.00
# interval_33      0.00
# interval_34      0.00
# interval_35      0.00
# interval_36      0.00
# interval_37      0.04
# interval_38      0.04
# interval_39      0.03
# interval_40      0.04
# interval_41      0.04
# interval_42      0.04
# interval_43      0.04
# interval_44      0.04
# interval_45      0.03
# interval_46      0.04
# interval_47      0.04
# interval_48      0.04
# cluster_label    0.00
# dtype: float64
#
# max =
# interval_1       6.95
# interval_2       6.39
# interval_3       5.51
# interval_4       3.98
# interval_5       4.16
# interval_6       6.08
# interval_7       6.09
# interval_8       6.15
# interval_9       5.82
# interval_10      3.98
# interval_11      3.83
# interval_12      6.04
# interval_13      6.04
# interval_14      6.11
# interval_15      5.99
# interval_16      6.11
# interval_17      5.56
# interval_18      6.06
# interval_19      6.35
# interval_20      5.90
# interval_21      6.14
# interval_22      5.91
# interval_23      5.96
# interval_24      5.99
# interval_25      6.02
# interval_26      5.94
# interval_27      5.98
# interval_28      5.88
# interval_29      3.77
# interval_30      3.23
# interval_31      4.04
# interval_32      4.39
# interval_33      5.26
# interval_34      4.41
# interval_35      5.04
# interval_36      6.56
# interval_37      6.38
# interval_38      6.36
# interval_39      6.32
# interval_40      6.28
# interval_41      6.16
# interval_42      5.94
# interval_43      5.96
# interval_44      6.44
# interval_45      6.30
# interval_46      6.10
# interval_47      6.14
# interval_48      6.09
# cluster_label    0.00
# dtype: float64
#
# median =
# interval_1       0.22
# interval_2       0.21
# interval_3       0.20
# interval_4       0.19
# interval_5       0.19
# interval_6       0.18
# interval_7       0.18
# interval_8       0.17
# interval_9       0.18
# interval_10      0.18
# interval_11      0.19
# interval_12      0.20
# interval_13      0.28
# interval_14      0.31
# interval_15      0.33
# interval_16      0.38
# interval_17      0.36
# interval_18      0.32
# interval_19      0.31
# interval_20      0.29
# interval_21      0.25
# interval_22      0.20
# interval_23      0.19
# interval_24      0.20
# interval_25      0.19
# interval_26      0.19
# interval_27      0.19
# interval_28      0.18
# interval_29      0.19
# interval_30      0.22
# interval_31      0.21
# interval_32      0.22
# interval_33      0.24
# interval_34      0.29
# interval_35      0.33
# interval_36      0.35
# interval_37      0.40
# interval_38      0.44
# interval_39      0.46
# interval_40      0.47
# interval_41      0.46
# interval_42      0.47
# interval_43      0.46
# interval_44      0.43
# interval_45      0.37
# interval_46      0.33
# interval_47      0.27
# interval_48      0.24
# cluster_label    0.00
# dtype: float64
#
# std =
# interval_1       0.68
# interval_2       0.59
# interval_3       0.55
# interval_4       0.49
# interval_5       0.51
# interval_6       0.59
# interval_7       0.72
# interval_8       0.73
# interval_9       0.75
# interval_10      0.46
# interval_11      0.41
# interval_12      0.48
# interval_13      0.53
# interval_14      0.67
# interval_15      0.55
# interval_16      0.64
# interval_17      0.69
# interval_18      0.70
# interval_19      0.74
# interval_20      0.72
# interval_21      0.70
# interval_22      0.71
# interval_23      0.71
# interval_24      0.76
# interval_25      0.74
# interval_26      0.79
# interval_27      0.78
# interval_28      0.68
# interval_29      0.62
# interval_30      0.58
# interval_31      0.59
# interval_32      0.63
# interval_33      0.68
# interval_34      0.63
# interval_35      0.67
# interval_36      0.75
# interval_37      0.78
# interval_38      0.84
# interval_39      0.82
# interval_40      0.85
# interval_41      0.82
# interval_42      0.82
# interval_43      0.78
# interval_44      0.80
# interval_45      0.77
# interval_46      0.77
# interval_47      0.78
# interval_48      0.73
# cluster_label    0.00
# dtype: float64
# --------------------------------------------------
#
# Cluster 1:
# Size: 376 samples (10.32%)
# mean =
# interval_1       0.61
# interval_2       0.61
# interval_3       0.56
# interval_4       0.53
# interval_5       0.43
# interval_6       0.37
# interval_7       0.28
# interval_8       0.26
# interval_9       0.28
# interval_10      0.27
# interval_11      0.27
# interval_12      0.40
# interval_13      0.31
# interval_14      0.33
# interval_15      0.30
# interval_16      0.24
# interval_17      0.21
# interval_18      0.18
# interval_19      0.17
# interval_20      0.16
# interval_21      0.15
# interval_22      0.14
# interval_23      0.15
# interval_24      0.13
# interval_25      0.14
# interval_26      0.18
# interval_27      0.19
# interval_28      0.24
# interval_29      0.26
# interval_30      0.31
# interval_31      0.39
# interval_32      0.40
# interval_33      0.40
# interval_34      0.48
# interval_35      0.57
# interval_36      0.63
# interval_37      0.65
# interval_38      0.65
# interval_39      0.62
# interval_40      0.63
# interval_41      0.54
# interval_42      0.53
# interval_43      0.46
# interval_44      0.42
# interval_45      0.38
# interval_46      0.37
# interval_47      0.57
# interval_48      0.58
# cluster_label    1.00
# dtype: float64
#
# min =
# interval_1       0.03
# interval_2       0.04
# interval_3       0.04
# interval_4       0.04
# interval_5       0.04
# interval_6       0.03
# interval_7       0.04
# interval_8       0.03
# interval_9       0.04
# interval_10      0.03
# interval_11      0.03
# interval_12      0.03
# interval_13      0.03
# interval_14      0.00
# interval_15      0.00
# interval_16      0.00
# interval_17      0.00
# interval_18      0.00
# interval_19      0.00
# interval_20      0.00
# interval_21      0.00
# interval_22      0.00
# interval_23      0.00
# interval_24      0.00
# interval_25      0.00
# interval_26      0.00
# interval_27      0.00
# interval_28      0.00
# interval_29      0.00
# interval_30      0.00
# interval_31      0.00
# interval_32      0.00
# interval_33      0.00
# interval_34      0.00
# interval_35      0.00
# interval_36      0.00
# interval_37      0.02
# interval_38      0.04
# interval_39      0.04
# interval_40      0.04
# interval_41      0.04
# interval_42      0.03
# interval_43      0.03
# interval_44      0.04
# interval_45      0.03
# interval_46      0.04
# interval_47      0.03
# interval_48      0.04
# cluster_label    1.00
# dtype: float64
#
# max =
# interval_1       8.32
# interval_2       8.31
# interval_3       8.34
# interval_4       8.32
# interval_5       8.38
# interval_6       8.35
# interval_7       7.38
# interval_8       7.26
# interval_9       7.29
# interval_10      2.24
# interval_11      2.23
# interval_12      2.26
# interval_13      1.96
# interval_14      2.07
# interval_15      2.11
# interval_16      1.83
# interval_17      1.79
# interval_18      2.01
# interval_19      6.90
# interval_20      5.86
# interval_21      6.29
# interval_22      6.32
# interval_23      5.70
# interval_24      3.09
# interval_25      3.20
# interval_26      5.69
# interval_27      5.66
# interval_28      6.01
# interval_29      5.96
# interval_30      5.99
# interval_31      5.68
# interval_32      6.20
# interval_33      6.01
# interval_34      7.55
# interval_35      9.90
# interval_36      9.82
# interval_37      8.11
# interval_38      7.74
# interval_39      7.46
# interval_40      7.42
# interval_41      7.55
# interval_42      7.45
# interval_43      7.55
# interval_44      7.28
# interval_45      7.16
# interval_46      7.42
# interval_47      8.36
# interval_48      8.38
# cluster_label    1.00
# dtype: float64
#
# median =
# interval_1       0.15
# interval_2       0.14
# interval_3       0.14
# interval_4       0.14
# interval_5       0.13
# interval_6       0.13
# interval_7       0.13
# interval_8       0.12
# interval_9       0.12
# interval_10      0.14
# interval_11      0.14
# interval_12      0.15
# interval_13      0.18
# interval_14      0.19
# interval_15      0.17
# interval_16      0.14
# interval_17      0.09
# interval_18      0.07
# interval_19      0.05
# interval_20      0.05
# interval_21      0.05
# interval_22      0.04
# interval_23      0.04
# interval_24      0.04
# interval_25      0.04
# interval_26      0.04
# interval_27      0.04
# interval_28      0.04
# interval_29      0.05
# interval_30      0.05
# interval_31      0.07
# interval_32      0.08
# interval_33      0.10
# interval_34      0.15
# interval_35      0.24
# interval_36      0.35
# interval_37      0.37
# interval_38      0.39
# interval_39      0.38
# interval_40      0.39
# interval_41      0.31
# interval_42      0.31
# interval_43      0.23
# interval_44      0.20
# interval_45      0.16
# interval_46      0.14
# interval_47      0.16
# interval_48      0.15
# cluster_label    1.00
# dtype: float64
#
# std =
# interval_1       0.90
# interval_2       0.91
# interval_3       0.88
# interval_4       0.79
# interval_5       0.67
# interval_6       0.60
# interval_7       0.49
# interval_8       0.48
# interval_9       0.49
# interval_10      0.34
# interval_11      0.33
# interval_12      0.50
# interval_13      0.33
# interval_14      0.36
# interval_15      0.35
# interval_16      0.29
# interval_17      0.28
# interval_18      0.30
# interval_19      0.45
# interval_20      0.42
# interval_21      0.43
# interval_22      0.43
# interval_23      0.45
# interval_24      0.33
# interval_25      0.34
# interval_26      0.55
# interval_27      0.63
# interval_28      0.78
# interval_29      0.82
# interval_30      0.79
# interval_31      0.89
# interval_32      0.86
# interval_33      0.78
# interval_34      0.87
# interval_35      1.00
# interval_36      0.98
# interval_37      0.92
# interval_38      0.84
# interval_39      0.82
# interval_40      0.84
# interval_41      0.71
# interval_42      0.66
# interval_43      0.67
# interval_44      0.65
# interval_45      0.64
# interval_46      0.71
# interval_47      0.84
# interval_48      0.87
# cluster_label    0.00
# dtype: float64
# --------------------------------------------------
#
# Cluster 2:
# Size: 40 samples (1.1%)
# mean =
# interval_1       0.05
# interval_2       0.06
# interval_3       0.12
# interval_4       0.12
# interval_5       0.05
# interval_6       0.05
# interval_7       0.05
# interval_8       0.05
# interval_9       0.04
# interval_10      0.05
# interval_11      0.04
# interval_12      0.07
# interval_13      0.80
# interval_14      0.62
# interval_15      0.56
# interval_16      0.41
# interval_17      0.16
# interval_18      0.17
# interval_19      0.16
# interval_20      0.12
# interval_21      0.11
# interval_22      0.11
# interval_23      0.08
# interval_24      0.10
# interval_25      0.07
# interval_26      0.10
# interval_27      0.14
# interval_28      0.14
# interval_29      0.11
# interval_30      0.05
# interval_31      0.09
# interval_32      0.10
# interval_33      0.16
# interval_34      0.12
# interval_35      0.09
# interval_36      0.10
# interval_37      0.12
# interval_38      0.13
# interval_39      0.19
# interval_40      0.18
# interval_41      0.14
# interval_42      0.10
# interval_43      0.08
# interval_44      0.06
# interval_45      0.05
# interval_46      0.05
# interval_47      0.05
# interval_48      0.05
# cluster_label    2.00
# dtype: float64
#
# min =
# interval_1       0.01
# interval_2       0.04
# interval_3       0.11
# interval_4       0.11
# interval_5       0.02
# interval_6       0.01
# interval_7       0.01
# interval_8       0.01
# interval_9       0.01
# interval_10      0.01
# interval_11      0.01
# interval_12      0.01
# interval_13      0.06
# interval_14      0.07
# interval_15      0.14
# interval_16      0.12
# interval_17      0.03
# interval_18      0.03
# interval_19      0.02
# interval_20      0.02
# interval_21      0.02
# interval_22      0.02
# interval_23      0.02
# interval_24      0.04
# interval_25      0.03
# interval_26      0.04
# interval_27      0.12
# interval_28      0.11
# interval_29      0.04
# interval_30      0.01
# interval_31      0.03
# interval_32      0.02
# interval_33      0.04
# interval_34      0.03
# interval_35      0.04
# interval_36      0.04
# interval_37      0.02
# interval_38      0.06
# interval_39      0.17
# interval_40      0.18
# interval_41      0.09
# interval_42      0.05
# interval_43      0.02
# interval_44      0.01
# interval_45      0.01
# interval_46      0.01
# interval_47      0.01
# interval_48      0.01
# cluster_label    2.00
# dtype: float64
#
# max =
# interval_1       0.11
# interval_2       0.12
# interval_3       0.13
# interval_4       0.13
# interval_5       0.11
# interval_6       0.07
# interval_7       0.11
# interval_8       0.09
# interval_9       0.09
# interval_10      0.09
# interval_11      0.09
# interval_12      0.22
# interval_13      1.29
# interval_14      1.17
# interval_15      1.19
# interval_16      1.75
# interval_17      1.04
# interval_18      1.07
# interval_19      1.04
# interval_20      0.50
# interval_21      0.88
# interval_22      0.48
# interval_23      0.36
# interval_24      0.31
# interval_25      0.22
# interval_26      0.29
# interval_27      0.34
# interval_28      0.35
# interval_29      0.36
# interval_30      0.31
# interval_31      0.28
# interval_32      0.32
# interval_33      0.98
# interval_34      0.40
# interval_35      0.32
# interval_36      0.41
# interval_37      0.28
# interval_38      0.26
# interval_39      0.20
# interval_40      0.19
# interval_41      0.18
# interval_42      0.14
# interval_43      0.16
# interval_44      0.13
# interval_45      0.12
# interval_46      0.11
# interval_47      0.09
# interval_48      0.10
# cluster_label    2.00
# dtype: float64
#
# median =
# interval_1       0.05
# interval_2       0.05
# interval_3       0.12
# interval_4       0.12
# interval_5       0.05
# interval_6       0.05
# interval_7       0.04
# interval_8       0.06
# interval_9       0.03
# interval_10      0.06
# interval_11      0.03
# interval_12      0.06
# interval_13      0.96
# interval_14      0.68
# interval_15      0.49
# interval_16      0.14
# interval_17      0.08
# interval_18      0.08
# interval_19      0.08
# interval_20      0.08
# interval_21      0.06
# interval_22      0.09
# interval_23      0.05
# interval_24      0.10
# interval_25      0.06
# interval_26      0.10
# interval_27      0.13
# interval_28      0.13
# interval_29      0.10
# interval_30      0.03
# interval_31      0.08
# interval_32      0.08
# interval_33      0.11
# interval_34      0.09
# interval_35      0.09
# interval_36      0.09
# interval_37      0.12
# interval_38      0.12
# interval_39      0.19
# interval_40      0.18
# interval_41      0.14
# interval_42      0.10
# interval_43      0.08
# interval_44      0.07
# interval_45      0.04
# interval_46      0.06
# interval_47      0.04
# interval_48      0.06
# cluster_label    2.00
# dtype: float64
#
# std =
# interval_1       0.03
# interval_2       0.02
# interval_3       0.01
# interval_4       0.00
# interval_5       0.03
# interval_6       0.02
# interval_7       0.02
# interval_8       0.02
# interval_9       0.02
# interval_10      0.02
# interval_11      0.02
# interval_12      0.05
# interval_13      0.40
# interval_14      0.47
# interval_15      0.43
# interval_16      0.42
# interval_17      0.23
# interval_18      0.21
# interval_19      0.23
# interval_20      0.13
# interval_21      0.16
# interval_22      0.09
# interval_23      0.07
# interval_24      0.05
# interval_25      0.04
# interval_26      0.04
# interval_27      0.04
# interval_28      0.05
# interval_29      0.05
# interval_30      0.05
# interval_31      0.05
# interval_32      0.07
# interval_33      0.15
# interval_34      0.08
# interval_35      0.05
# interval_36      0.07
# interval_37      0.05
# interval_38      0.03
# interval_39      0.01
# interval_40      0.00
# interval_41      0.03
# interval_42      0.02
# interval_43      0.04
# interval_44      0.03
# interval_45      0.03
# interval_46      0.03
# interval_47      0.02
# interval_48      0.02
# cluster_label    0.00
# dtype: float64
# --------------------------------------------------
#
# Cluster 3:
# Size: 44 samples (1.21%)
# mean =
# interval_1       0.47
# interval_2       0.48
# interval_3       0.45
# interval_4       0.45
# interval_5       0.46
# interval_6       0.47
# interval_7       0.50
# interval_8       0.50
# interval_9       0.51
# interval_10      0.56
# interval_11      0.56
# interval_12      0.55
# interval_13      0.57
# interval_14      0.53
# interval_15      1.29
# interval_16      1.01
# interval_17      0.70
# interval_18      0.47
# interval_19      0.16
# interval_20      0.13
# interval_21      0.12
# interval_22      0.10
# interval_23      0.01
# interval_24      0.01
# interval_25      0.00
# interval_26      0.01
# interval_27      0.06
# interval_28      0.11
# interval_29      0.14
# interval_30      0.21
# interval_31      0.17
# interval_32      0.04
# interval_33      0.07
# interval_34      0.09
# interval_35      0.13
# interval_36      0.17
# interval_37      0.21
# interval_38      0.26
# interval_39      0.31
# interval_40      0.28
# interval_41      0.18
# interval_42      0.21
# interval_43      0.35
# interval_44      0.42
# interval_45      0.42
# interval_46      0.52
# interval_47      0.55
# interval_48      0.47
# cluster_label    3.00
# dtype: float64
#
# min =
# interval_1       0.00
# interval_2       0.00
# interval_3       0.00
# interval_4       0.00
# interval_5       0.00
# interval_6       0.00
# interval_7       0.00
# interval_8       0.00
# interval_9       0.00
# interval_10      0.09
# interval_11      0.44
# interval_12      0.45
# interval_13      0.44
# interval_14      0.05
# interval_15      0.48
# interval_16      0.06
# interval_17      0.01
# interval_18      0.01
# interval_19      0.00
# interval_20      0.00
# interval_21      0.00
# interval_22      0.00
# interval_23      0.00
# interval_24      0.00
# interval_25      0.00
# interval_26      0.00
# interval_27      0.00
# interval_28      0.00
# interval_29      0.00
# interval_30      0.00
# interval_31      0.00
# interval_32      0.00
# interval_33      0.00
# interval_34      0.00
# interval_35      0.00
# interval_36      0.00
# interval_37      0.00
# interval_38      0.00
# interval_39      0.00
# interval_40      0.00
# interval_41      0.00
# interval_42      0.00
# interval_43      0.00
# interval_44      0.00
# interval_45      0.00
# interval_46      0.00
# interval_47      0.00
# interval_48      0.00
# cluster_label    3.00
# dtype: float64
#
# max =
# interval_1       1.68
# interval_2       1.36
# interval_3       1.01
# interval_4       1.04
# interval_5       1.00
# interval_6       1.02
# interval_7       1.05
# interval_8       1.00
# interval_9       0.86
# interval_10      0.92
# interval_11      0.79
# interval_12      0.82
# interval_13      0.84
# interval_14      1.09
# interval_15      1.84
# interval_16      1.90
# interval_17      2.69
# interval_18      6.86
# interval_19      5.32
# interval_20      4.91
# interval_21      3.19
# interval_22      4.00
# interval_23      0.28
# interval_24      0.02
# interval_25      0.02
# interval_26      0.38
# interval_27      1.78
# interval_28      3.20
# interval_29      3.51
# interval_30      3.66
# interval_31      3.78
# interval_32      0.85
# interval_33      1.92
# interval_34      2.60
# interval_35      3.18
# interval_36      3.85
# interval_37      6.30
# interval_38      6.18
# interval_39      6.34
# interval_40      5.01
# interval_41      1.54
# interval_42      1.50
# interval_43      4.08
# interval_44      5.94
# interval_45      6.32
# interval_46      6.16
# interval_47      6.16
# interval_48      2.74
# cluster_label    3.00
# dtype: float64
#
# median =
# interval_1       0.46
# interval_2       0.47
# interval_3       0.47
# interval_4       0.48
# interval_5       0.48
# interval_6       0.49
# interval_7       0.49
# interval_8       0.48
# interval_9       0.50
# interval_10      0.54
# interval_11      0.56
# interval_12      0.54
# interval_13      0.56
# interval_14      0.57
# interval_15      1.34
# interval_16      1.02
# interval_17      0.54
# interval_18      0.04
# interval_19      0.01
# interval_20      0.01
# interval_21      0.01
# interval_22      0.01
# interval_23      0.00
# interval_24      0.00
# interval_25      0.00
# interval_26      0.00
# interval_27      0.00
# interval_28      0.00
# interval_29      0.00
# interval_30      0.00
# interval_31      0.00
# interval_32      0.00
# interval_33      0.00
# interval_34      0.00
# interval_35      0.00
# interval_36      0.01
# interval_37      0.02
# interval_38      0.04
# interval_39      0.01
# interval_40      0.01
# interval_41      0.01
# interval_42      0.01
# interval_43      0.01
# interval_44      0.01
# interval_45      0.01
# interval_46      0.01
# interval_47      0.05
# interval_48      0.42
# cluster_label    3.00
# dtype: float64
#
# std =
# interval_1       0.38
# interval_2       0.37
# interval_3       0.32
# interval_4       0.29
# interval_5       0.25
# interval_6       0.22
# interval_7       0.19
# interval_8       0.17
# interval_9       0.14
# interval_10      0.12
# interval_11      0.08
# interval_12      0.10
# interval_13      0.10
# interval_14      0.19
# interval_15      0.32
# interval_16      0.43
# interval_17      0.64
# interval_18      1.08
# interval_19      0.80
# interval_20      0.74
# interval_21      0.53
# interval_22      0.60
# interval_23      0.04
# interval_24      0.01
# interval_25      0.01
# interval_26      0.06
# interval_27      0.28
# interval_28      0.52
# interval_29      0.65
# interval_30      0.80
# interval_31      0.75
# interval_32      0.16
# interval_33      0.31
# interval_34      0.41
# interval_35      0.53
# interval_36      0.64
# interval_37      0.95
# interval_38      0.94
# interval_39      1.03
# interval_40      0.83
# interval_41      0.38
# interval_42      0.39
# interval_43      0.71
# interval_44      0.97
# interval_45      1.00
# interval_46      1.03
# interval_47      1.01
# interval_48      0.57
# cluster_label    0.00
# dtype: float64
# --------------------------------------------------
#
# Cluster 4:
# Size: 2344 samples (64.34%)
# mean =
# interval_1       0.20
# interval_2       0.19
# interval_3       0.17
# interval_4       0.17
# interval_5       0.16
# interval_6       0.15
# interval_7       0.15
# interval_8       0.15
# interval_9       0.14
# interval_10      0.14
# interval_11      0.14
# interval_12      0.15
# interval_13      0.17
# interval_14      0.20
# interval_15      0.19
# interval_16      0.18
# interval_17      0.18
# interval_18      0.18
# interval_19      0.18
# interval_20      0.18
# interval_21      0.17
# interval_22      0.18
# interval_23      0.17
# interval_24      0.18
# interval_25      0.18
# interval_26      0.18
# interval_27      0.18
# interval_28      0.19
# interval_29      0.19
# interval_30      0.19
# interval_31      0.20
# interval_32      0.21
# interval_33      0.23
# interval_34      0.24
# interval_35      0.26
# interval_36      0.28
# interval_37      0.29
# interval_38      0.29
# interval_39      0.28
# interval_40      0.27
# interval_41      0.27
# interval_42      0.26
# interval_43      0.26
# interval_44      0.25
# interval_45      0.24
# interval_46      0.23
# interval_47      0.21
# interval_48      0.21
# cluster_label    4.00
# dtype: float64
#
# min =
# interval_1       0.0
# interval_2       0.0
# interval_3       0.0
# interval_4       0.0
# interval_5       0.0
# interval_6       0.0
# interval_7       0.0
# interval_8       0.0
# interval_9       0.0
# interval_10      0.0
# interval_11      0.0
# interval_12      0.0
# interval_13      0.0
# interval_14      0.0
# interval_15      0.0
# interval_16      0.0
# interval_17      0.0
# interval_18      0.0
# interval_19      0.0
# interval_20      0.0
# interval_21      0.0
# interval_22      0.0
# interval_23      0.0
# interval_24      0.0
# interval_25      0.0
# interval_26      0.0
# interval_27      0.0
# interval_28      0.0
# interval_29      0.0
# interval_30      0.0
# interval_31      0.0
# interval_32      0.0
# interval_33      0.0
# interval_34      0.0
# interval_35      0.0
# interval_36      0.0
# interval_37      0.0
# interval_38      0.0
# interval_39      0.0
# interval_40      0.0
# interval_41      0.0
# interval_42      0.0
# interval_43      0.0
# interval_44      0.0
# interval_45      0.0
# interval_46      0.0
# interval_47      0.0
# interval_48      0.0
# cluster_label    4.0
# dtype: float64
#
# max =
# interval_1       5.68
# interval_2       5.61
# interval_3       5.59
# interval_4       5.66
# interval_5       5.54
# interval_6       4.04
# interval_7       5.54
# interval_8       5.60
# interval_9       4.89
# interval_10      4.28
# interval_11      4.47
# interval_12      4.82
# interval_13      2.56
# interval_14      2.78
# interval_15      2.74
# interval_16      2.94
# interval_17      2.95
# interval_18      3.63
# interval_19      3.98
# interval_20      3.90
# interval_21      3.91
# interval_22      5.50
# interval_23      5.58
# interval_24      5.35
# interval_25      5.20
# interval_26      5.09
# interval_27      5.41
# interval_28      5.34
# interval_29      5.44
# interval_30      5.52
# interval_31      3.55
# interval_32      3.50
# interval_33      3.46
# interval_34      5.14
# interval_35      3.96
# interval_36      3.50
# interval_37      4.12
# interval_38      5.58
# interval_39      5.56
# interval_40      5.58
# interval_41      5.48
# interval_42      5.54
# interval_43      5.54
# interval_44      5.65
# interval_45      6.19
# interval_46      5.71
# interval_47      5.71
# interval_48      5.72
# cluster_label    4.00
# dtype: float64
#
# median =
# interval_1       0.11
# interval_2       0.11
# interval_3       0.10
# interval_4       0.10
# interval_5       0.10
# interval_6       0.10
# interval_7       0.10
# interval_8       0.10
# interval_9       0.10
# interval_10      0.10
# interval_11      0.10
# interval_12      0.11
# interval_13      0.12
# interval_14      0.13
# interval_15      0.13
# interval_16      0.12
# interval_17      0.12
# interval_18      0.11
# interval_19      0.11
# interval_20      0.11
# interval_21      0.11
# interval_22      0.10
# interval_23      0.10
# interval_24      0.11
# interval_25      0.11
# interval_26      0.11
# interval_27      0.11
# interval_28      0.10
# interval_29      0.11
# interval_30      0.11
# interval_31      0.11
# interval_32      0.12
# interval_33      0.12
# interval_34      0.14
# interval_35      0.14
# interval_36      0.16
# interval_37      0.18
# interval_38      0.19
# interval_39      0.19
# interval_40      0.19
# interval_41      0.18
# interval_42      0.18
# interval_43      0.17
# interval_44      0.16
# interval_45      0.14
# interval_46      0.13
# interval_47      0.12
# interval_48      0.12
# cluster_label    4.00
# dtype: float64
#
# std =
# interval_1       0.40
# interval_2       0.37
# interval_3       0.33
# interval_4       0.32
# interval_5       0.29
# interval_6       0.25
# interval_7       0.26
# interval_8       0.26
# interval_9       0.23
# interval_10      0.21
# interval_11      0.19
# interval_12      0.20
# interval_13      0.19
# interval_14      0.24
# interval_15      0.24
# interval_16      0.22
# interval_17      0.24
# interval_18      0.24
# interval_19      0.26
# interval_20      0.26
# interval_21      0.26
# interval_22      0.30
# interval_23      0.29
# interval_24      0.28
# interval_25      0.28
# interval_26      0.30
# interval_27      0.30
# interval_28      0.31
# interval_29      0.33
# interval_30      0.33
# interval_31      0.33
# interval_32      0.34
# interval_33      0.35
# interval_34      0.37
# interval_35      0.38
# interval_36      0.38
# interval_37      0.38
# interval_38      0.37
# interval_39      0.35
# interval_40      0.34
# interval_41      0.39
# interval_42      0.39
# interval_43      0.40
# interval_44      0.41
# interval_45      0.43
# interval_46      0.42
# interval_47      0.42
# interval_48      0.42
# cluster_label    0.00
# dtype: float64
# --------------------------------------------------
#
# Cluster 5:
# Size: 121 samples (3.32%)
# mean =
# interval_1       1.61
# interval_2       1.40
# interval_3       1.25
# interval_4       1.02
# interval_5       0.86
# interval_6       0.87
# interval_7       1.21
# interval_8       1.29
# interval_9       1.34
# interval_10      0.89
# interval_11      0.71
# interval_12      0.64
# interval_13      0.43
# interval_14      0.46
# interval_15      0.45
# interval_16      0.46
# interval_17      0.56
# interval_18      0.59
# interval_19      0.57
# interval_20      0.64
# interval_21      0.66
# interval_22      0.66
# interval_23      0.67
# interval_24      0.68
# interval_25      0.71
# interval_26      0.70
# interval_27      0.73
# interval_28      0.72
# interval_29      0.75
# interval_30      0.77
# interval_31      0.68
# interval_32      0.67
# interval_33      0.61
# interval_34      0.64
# interval_35      0.65
# interval_36      0.66
# interval_37      0.76
# interval_38      0.90
# interval_39      0.93
# interval_40      0.88
# interval_41      0.82
# interval_42      0.80
# interval_43      0.78
# interval_44      0.62
# interval_45      0.97
# interval_46      0.88
# interval_47      1.66
# interval_48      1.69
# cluster_label    5.00
# dtype: float64
#
# min =
# interval_1       0.17
# interval_2       0.16
# interval_3       0.15
# interval_4       0.14
# interval_5       0.16
# interval_6       0.14
# interval_7       0.16
# interval_8       0.12
# interval_9       0.09
# interval_10      0.12
# interval_11      0.09
# interval_12      0.14
# interval_13      0.09
# interval_14      0.00
# interval_15      0.00
# interval_16      0.00
# interval_17      0.00
# interval_18      0.00
# interval_19      0.00
# interval_20      0.00
# interval_21      0.00
# interval_22      0.00
# interval_23      0.00
# interval_24      0.00
# interval_25      0.00
# interval_26      0.00
# interval_27      0.00
# interval_28      0.00
# interval_29      0.00
# interval_30      0.00
# interval_31      0.00
# interval_32      0.00
# interval_33      0.00
# interval_34      0.00
# interval_35      0.00
# interval_36      0.00
# interval_37      0.06
# interval_38      0.18
# interval_39      0.19
# interval_40      0.19
# interval_41      0.18
# interval_42      0.19
# interval_43      0.16
# interval_44      0.17
# interval_45      0.16
# interval_46      0.17
# interval_47      0.16
# interval_48      0.16
# cluster_label    5.00
# dtype: float64
#
# max =
# interval_1        8.06
# interval_2       12.71
# interval_3       12.40
# interval_4       12.39
# interval_5        9.20
# interval_6        4.25
# interval_7       12.10
# interval_8       12.18
# interval_9       12.20
# interval_10      12.22
# interval_11      12.19
# interval_12       2.17
# interval_13       2.00
# interval_14       1.75
# interval_15       2.29
# interval_16       2.36
# interval_17       2.98
# interval_18       2.81
# interval_19       2.79
# interval_20       4.04
# interval_21       3.72
# interval_22       4.49
# interval_23       4.71
# interval_24       4.85
# interval_25       5.14
# interval_26       4.72
# interval_27       5.94
# interval_28       4.72
# interval_29       4.03
# interval_30      12.45
# interval_31      12.02
# interval_32       8.91
# interval_33       4.36
# interval_34       5.51
# interval_35       4.91
# interval_36       3.79
# interval_37       3.99
# interval_38       8.86
# interval_39      12.30
# interval_40      12.22
# interval_41       5.64
# interval_42       8.66
# interval_43      12.95
# interval_44       4.03
# interval_45       4.72
# interval_46       4.59
# interval_47       6.96
# interval_48       6.91
# cluster_label     5.00
# dtype: float64
#
# median =
# interval_1       0.51
# interval_2       0.50
# interval_3       0.49
# interval_4       0.46
# interval_5       0.29
# interval_6       0.45
# interval_7       0.49
# interval_8       0.46
# interval_9       0.50
# interval_10      0.46
# interval_11      0.28
# interval_12      0.49
# interval_13      0.38
# interval_14      0.39
# interval_15      0.30
# interval_16      0.26
# interval_17      0.26
# interval_18      0.24
# interval_19      0.23
# interval_20      0.26
# interval_21      0.28
# interval_22      0.27
# interval_23      0.25
# interval_24      0.26
# interval_25      0.25
# interval_26      0.21
# interval_27      0.31
# interval_28      0.37
# interval_29      0.57
# interval_30      0.48
# interval_31      0.48
# interval_32      0.45
# interval_33      0.46
# interval_34      0.44
# interval_35      0.48
# interval_36      0.51
# interval_37      0.57
# interval_38      0.59
# interval_39      0.57
# interval_40      0.59
# interval_41      0.55
# interval_42      0.54
# interval_43      0.54
# interval_44      0.46
# interval_45      0.49
# interval_46      0.40
# interval_47      0.57
# interval_48      0.52
# cluster_label    5.00
# dtype: float64
#
# std =
# interval_1       2.04
# interval_2       1.98
# interval_3       1.86
# interval_4       1.67
# interval_5       1.42
# interval_6       1.13
# interval_7       1.97
# interval_8       1.99
# interval_9       2.04
# interval_10      1.46
# interval_11      1.39
# interval_12      0.46
# interval_13      0.25
# interval_14      0.36
# interval_15      0.44
# interval_16      0.49
# interval_17      0.64
# interval_18      0.70
# interval_19      0.69
# interval_20      0.77
# interval_21      0.80
# interval_22      0.86
# interval_23      0.88
# interval_24      0.87
# interval_25      0.89
# interval_26      0.93
# interval_27      0.97
# interval_28      0.87
# interval_29      0.85
# interval_30      1.32
# interval_31      1.24
# interval_32      1.06
# interval_33      0.83
# interval_34      0.89
# interval_35      0.77
# interval_36      0.64
# interval_37      0.67
# interval_38      0.99
# interval_39      1.24
# interval_40      1.22
# interval_41      0.84
# interval_42      1.04
# interval_43      1.30
# interval_44      0.65
# interval_45      1.26
# interval_46      1.22
# interval_47      1.95
# interval_48      2.06
# cluster_label    0.00
# dtype: float64
# --------------------------------------------------
#
# Statistik detail per cluster:
# {np.int64(0): {'mean': interval_1       0.476026
# interval_2       0.426211
# interval_3       0.395360
# interval_4       0.365462
# interval_5       0.367982
# interval_6       0.374527
# interval_7       0.400521
# interval_8       0.401923
# interval_9       0.428911
# interval_10      0.375906
# interval_11      0.352187
# interval_12      0.363412
# interval_13      0.444137
# interval_14      0.550304
# interval_15      0.503777
# interval_16      0.567280
# interval_17      0.600207
# interval_18      0.565733
# interval_19      0.546997
# interval_20      0.531786
# interval_21      0.499358
# interval_22      0.492254
# interval_23      0.485778
# interval_24      0.515465
# interval_25      0.488121
# interval_26      0.497104
# interval_27      0.484380
# interval_28      0.456541
# interval_29      0.444747
# interval_30      0.452989
# interval_31      0.450755
# interval_32      0.475560
# interval_33      0.517359
# interval_34      0.547883
# interval_35      0.591465
# interval_36      0.641228
# interval_37      0.698125
# interval_38      0.748032
# interval_39      0.736506
# interval_40      0.757360
# interval_41      0.748174
# interval_42      0.770570
# interval_43      0.757243
# interval_44      0.710243
# interval_45      0.646569
# interval_46      0.609827
# interval_47      0.574203
# interval_48      0.521938
# cluster_label    0.000000
# dtype: float64, 'min': interval_1       0.0437
# interval_2       0.0312
# interval_3       0.0125
# interval_4       0.0125
# interval_5       0.0062
# interval_6       0.0125
# interval_7       0.0125
# interval_8       0.0062
# interval_9       0.0125
# interval_10      0.0375
# interval_11      0.0375
# interval_12      0.0375
# interval_13      0.0375
# interval_14      0.0375
# interval_15      0.0062
# interval_16      0.0000
# interval_17      0.0000
# interval_18      0.0000
# interval_19      0.0000
# interval_20      0.0000
# interval_21      0.0000
# interval_22      0.0000
# interval_23      0.0000
# interval_24      0.0000
# interval_25      0.0000
# interval_26      0.0000
# interval_27      0.0000
# interval_28      0.0000
# interval_29      0.0000
# interval_30      0.0000
# interval_31      0.0000
# interval_32      0.0000
# interval_33      0.0000
# interval_34      0.0000
# interval_35      0.0000
# interval_36      0.0000
# interval_37      0.0375
# interval_38      0.0375
# interval_39      0.0312
# interval_40      0.0375
# interval_41      0.0375
# interval_42      0.0375
# interval_43      0.0375
# interval_44      0.0375
# interval_45      0.0312
# interval_46      0.0375
# interval_47      0.0375
# interval_48      0.0375
# cluster_label    0.0000
# dtype: float64, 'max': interval_1       6.9500
# interval_2       6.3875
# interval_3       5.5125
# interval_4       3.9750
# interval_5       4.1625
# interval_6       6.0750
# interval_7       6.0875
# interval_8       6.1500
# interval_9       5.8250
# interval_10      3.9812
# interval_11      3.8312
# interval_12      6.0375
# interval_13      6.0375
# interval_14      6.1125
# interval_15      5.9875
# interval_16      6.1125
# interval_17      5.5625
# interval_18      6.0625
# interval_19      6.3500
# interval_20      5.9000
# interval_21      6.1375
# interval_22      5.9125
# interval_23      5.9625
# interval_24      5.9875
# interval_25      6.0250
# interval_26      5.9375
# interval_27      5.9750
# interval_28      5.8750
# interval_29      3.7670
# interval_30      3.2312
# interval_31      4.0375
# interval_32      4.3875
# interval_33      5.2625
# interval_34      4.4070
# interval_35      5.0360
# interval_36      6.5625
# interval_37      6.3750
# interval_38      6.3625
# interval_39      6.3250
# interval_40      6.2750
# interval_41      6.1625
# interval_42      5.9375
# interval_43      5.9625
# interval_44      6.4375
# interval_45      6.3000
# interval_46      6.1000
# interval_47      6.1375
# interval_48      6.0875
# cluster_label    0.0000
# dtype: float64, 'median': interval_1       0.22500
# interval_2       0.21250
# interval_3       0.19550
# interval_4       0.19100
# interval_5       0.18575
# interval_6       0.17550
# interval_7       0.17500
# interval_8       0.17350
# interval_9       0.17500
# interval_10      0.18110
# interval_11      0.18750
# interval_12      0.20000
# interval_13      0.27500
# interval_14      0.31275
# interval_15      0.33120
# interval_16      0.38110
# interval_17      0.36200
# interval_18      0.32500
# interval_19      0.30620
# interval_20      0.28750
# interval_21      0.24635
# interval_22      0.19500
# interval_23      0.19025
# interval_24      0.20400
# interval_25      0.19060
# interval_26      0.19200
# interval_27      0.18750
# interval_28      0.18210
# interval_29      0.18750
# interval_30      0.22000
# interval_31      0.21275
# interval_32      0.21525
# interval_33      0.23750
# interval_34      0.28750
# interval_35      0.33160
# interval_36      0.35150
# interval_37      0.40200
# interval_38      0.43750
# interval_39      0.45950
# interval_40      0.47450
# interval_41      0.46225
# interval_42      0.47000
# interval_43      0.45760
# interval_44      0.43400
# interval_45      0.36885
# interval_46      0.32700
# interval_47      0.26870
# interval_48      0.24400
# cluster_label    0.00000
# dtype: float64, 'std': interval_1       0.679830
# interval_2       0.592872
# interval_3       0.551377
# interval_4       0.493039
# interval_5       0.505463
# interval_6       0.592949
# interval_7       0.720928
# interval_8       0.730035
# interval_9       0.749926
# interval_10      0.463335
# interval_11      0.414377
# interval_12      0.476446
# interval_13      0.527539
# interval_14      0.665665
# interval_15      0.547965
# interval_16      0.643568
# interval_17      0.687958
# interval_18      0.697715
# interval_19      0.741576
# interval_20      0.718209
# interval_21      0.702189
# interval_22      0.714858
# interval_23      0.707088
# interval_24      0.757757
# interval_25      0.741841
# interval_26      0.794277
# interval_27      0.779544
# interval_28      0.680533
# interval_29      0.617384
# interval_30      0.575847
# interval_31      0.586442
# interval_32      0.626156
# interval_33      0.678017
# interval_34      0.634166
# interval_35      0.666306
# interval_36      0.746132
# interval_37      0.777108
# interval_38      0.842371
# interval_39      0.816458
# interval_40      0.847461
# interval_41      0.821832
# interval_42      0.820072
# interval_43      0.783031
# interval_44      0.803464
# interval_45      0.769917
# interval_46      0.773086
# interval_47      0.778444
# interval_48      0.725285
# cluster_label    0.000000
# dtype: float64}, np.int64(1): {'mean': interval_1       0.606832
# interval_2       0.607848
# interval_3       0.564843
# interval_4       0.525812
# interval_5       0.432906
# interval_6       0.365833
# interval_7       0.281656
# interval_8       0.263194
# interval_9       0.281765
# interval_10      0.272022
# interval_11      0.269401
# interval_12      0.396390
# interval_13      0.307996
# interval_14      0.332011
# interval_15      0.303396
# interval_16      0.242078
# interval_17      0.205405
# interval_18      0.181212
# interval_19      0.172700
# interval_20      0.164334
# interval_21      0.149831
# interval_22      0.141558
# interval_23      0.150446
# interval_24      0.129253
# interval_25      0.138023
# interval_26      0.177013
# interval_27      0.189657
# interval_28      0.238104
# interval_29      0.259845
# interval_30      0.308802
# interval_31      0.393686
# interval_32      0.399592
# interval_33      0.402251
# interval_34      0.477203
# interval_35      0.572797
# interval_36      0.626259
# interval_37      0.652016
# interval_38      0.645764
# interval_39      0.616622
# interval_40      0.627214
# interval_41      0.543914
# interval_42      0.526151
# interval_43      0.458953
# interval_44      0.416931
# interval_45      0.382831
# interval_46      0.368634
# interval_47      0.565743
# interval_48      0.576138
# cluster_label    1.000000
# dtype: float64, 'min': interval_1       0.0312
# interval_2       0.0375
# interval_3       0.0375
# interval_4       0.0375
# interval_5       0.0375
# interval_6       0.0312
# interval_7       0.0437
# interval_8       0.0312
# interval_9       0.0375
# interval_10      0.0312
# interval_11      0.0312
# interval_12      0.0312
# interval_13      0.0312
# interval_14      0.0000
# interval_15      0.0000
# interval_16      0.0000
# interval_17      0.0000
# interval_18      0.0000
# interval_19      0.0000
# interval_20      0.0000
# interval_21      0.0000
# interval_22      0.0000
# interval_23      0.0000
# interval_24      0.0000
# interval_25      0.0000
# interval_26      0.0000
# interval_27      0.0000
# interval_28      0.0000
# interval_29      0.0000
# interval_30      0.0000
# interval_31      0.0000
# interval_32      0.0000
# interval_33      0.0000
# interval_34      0.0000
# interval_35      0.0000
# interval_36      0.0000
# interval_37      0.0187
# interval_38      0.0375
# interval_39      0.0375
# interval_40      0.0375
# interval_41      0.0437
# interval_42      0.0312
# interval_43      0.0312
# interval_44      0.0375
# interval_45      0.0312
# interval_46      0.0375
# interval_47      0.0312
# interval_48      0.0375
# cluster_label    1.0000
# dtype: float64, 'max': interval_1       8.3250
# interval_2       8.3125
# interval_3       8.3375
# interval_4       8.3250
# interval_5       8.3750
# interval_6       8.3500
# interval_7       7.3750
# interval_8       7.2625
# interval_9       7.2875
# interval_10      2.2375
# interval_11      2.2312
# interval_12      2.2625
# interval_13      1.9562
# interval_14      2.0687
# interval_15      2.1125
# interval_16      1.8312
# interval_17      1.7875
# interval_18      2.0125
# interval_19      6.9000
# interval_20      5.8625
# interval_21      6.2875
# interval_22      6.3250
# interval_23      5.7000
# interval_24      3.0920
# interval_25      3.1960
# interval_26      5.6875
# interval_27      5.6625
# interval_28      6.0125
# interval_29      5.9625
# interval_30      5.9875
# interval_31      5.6750
# interval_32      6.2000
# interval_33      6.0060
# interval_34      7.5500
# interval_35      9.9000
# interval_36      9.8250
# interval_37      8.1125
# interval_38      7.7375
# interval_39      7.4625
# interval_40      7.4250
# interval_41      7.5500
# interval_42      7.4500
# interval_43      7.5500
# interval_44      7.2750
# interval_45      7.1625
# interval_46      7.4250
# interval_47      8.3625
# interval_48      8.3750
# cluster_label    1.0000
# dtype: float64, 'median': interval_1       0.15000
# interval_2       0.13825
# interval_3       0.14370
# interval_4       0.13750
# interval_5       0.13160
# interval_6       0.13120
# interval_7       0.12950
# interval_8       0.12500
# interval_9       0.12500
# interval_10      0.13650
# interval_11      0.13650
# interval_12      0.14800
# interval_13      0.17600
# interval_14      0.18600
# interval_15      0.16870
# interval_16      0.13750
# interval_17      0.09060
# interval_18      0.06870
# interval_19      0.05000
# interval_20      0.05000
# interval_21      0.05000
# interval_22      0.04060
# interval_23      0.04370
# interval_24      0.03825
# interval_25      0.03750
# interval_26      0.03750
# interval_27      0.03750
# interval_28      0.04370
# interval_29      0.05000
# interval_30      0.05000
# interval_31      0.06870
# interval_32      0.07500
# interval_33      0.10000
# interval_34      0.14800
# interval_35      0.24335
# interval_36      0.35000
# interval_37      0.37000
# interval_38      0.39060
# interval_39      0.37500
# interval_40      0.38975
# interval_41      0.31075
# interval_42      0.30935
# interval_43      0.23120
# interval_44      0.20000
# interval_45      0.16250
# interval_46      0.13750
# interval_47      0.15510
# interval_48      0.15000
# cluster_label    1.00000
# dtype: float64, 'std': interval_1       0.895296
# interval_2       0.912505
# interval_3       0.877655
# interval_4       0.789018
# interval_5       0.672985
# interval_6       0.598460
# interval_7       0.490163
# interval_8       0.481133
# interval_9       0.491017
# interval_10      0.336743
# interval_11      0.334118
# interval_12      0.502841
# interval_13      0.328969
# interval_14      0.364520
# interval_15      0.347592
# interval_16      0.288517
# interval_17      0.277764
# interval_18      0.295080
# interval_19      0.451644
# interval_20      0.416531
# interval_21      0.428229
# interval_22      0.429215
# interval_23      0.447935
# interval_24      0.334386
# interval_25      0.337791
# interval_26      0.545445
# interval_27      0.625708
# interval_28      0.779976
# interval_29      0.819631
# interval_30      0.794596
# interval_31      0.891744
# interval_32      0.860507
# interval_33      0.781351
# interval_34      0.872997
# interval_35      1.003153
# interval_36      0.980327
# interval_37      0.920370
# interval_38      0.844858
# interval_39      0.817830
# interval_40      0.836749
# interval_41      0.707462
# interval_42      0.661215
# interval_43      0.668405
# interval_44      0.649115
# interval_45      0.644172
# interval_46      0.708106
# interval_47      0.843134
# interval_48      0.872039
# cluster_label    0.000000
# dtype: float64}, np.int64(2): {'mean': interval_1       0.051540
# interval_2       0.062008
# interval_3       0.116382
# interval_4       0.118247
# interval_5       0.053573
# interval_6       0.051070
# interval_7       0.046538
# interval_8       0.051697
# interval_9       0.039663
# interval_10      0.054033
# interval_11      0.036222
# interval_12      0.071538
# interval_13      0.797473
# interval_14      0.618260
# interval_15      0.563408
# interval_16      0.412785
# interval_17      0.156690
# interval_18      0.167312
# interval_19      0.164972
# interval_20      0.117010
# interval_21      0.112165
# interval_22      0.107160
# interval_23      0.079040
# interval_24      0.101228
# interval_25      0.066848
# interval_26      0.104195
# interval_27      0.141690
# interval_28      0.142780
# interval_29      0.108407
# interval_30      0.051220
# interval_31      0.088413
# interval_32      0.101223
# interval_33      0.157475
# interval_34      0.118875
# interval_35      0.093567
# interval_36      0.104815
# interval_37      0.119975
# interval_38      0.130132
# interval_39      0.185602
# interval_40      0.182460
# interval_41      0.138880
# interval_42      0.099505
# interval_43      0.081540
# interval_44      0.060128
# interval_45      0.050133
# interval_46      0.052480
# interval_47      0.048250
# interval_48      0.050910
# cluster_label    2.000000
# dtype: float64, 'min': interval_1       0.0125
# interval_2       0.0375
# interval_3       0.1062
# interval_4       0.1125
# interval_5       0.0187
# interval_6       0.0125
# interval_7       0.0125
# interval_8       0.0125
# interval_9       0.0125
# interval_10      0.0125
# interval_11      0.0125
# interval_12      0.0125
# interval_13      0.0625
# interval_14      0.0687
# interval_15      0.1375
# interval_16      0.1250
# interval_17      0.0312
# interval_18      0.0312
# interval_19      0.0250
# interval_20      0.0187
# interval_21      0.0250
# interval_22      0.0250
# interval_23      0.0250
# ...
# interval_21      0.01250
# interval_22      0.01250
# interval_23      0.00000
# interval_24      0.00000
# interval_25      0.00000
# interval_26      0.00000
# interval_27      0.00000
# interval_28      0.00000
# interval_29      0.00000
# interval_30      0.00000
# interval_31      0.00000
# interval_32      0.00000
# interval_33      0.00000
# interval_34      0.00000
# interval_35      0.00000
# interval_36      0.01250
# interval_37      0.02500
# interval_38      0.03750
# interval_39      0.01250
# interval_40      0.01250
# interval_41      0.01250
# interval_42      0.01250
# interval_43      0.01250
# interval_44      0.01250
# interval_45      0.01250
# interval_46      0.01250
# interval_47      0.05000
# interval_48      0.42500
# cluster_label    3.00000
# dtype: float64, 'std': interval_1       0.383769
# interval_2       0.368012
# interval_3       0.315134
# interval_4       0.285400
# interval_5       0.246714
# interval_6       0.217586
# interval_7       0.187043
# interval_8       0.170104
# interval_9       0.139931
# interval_10      0.119212
# interval_11      0.079669
# interval_12      0.096365
# interval_13      0.101174
# interval_14      0.188613
# interval_15      0.315410
# interval_16      0.426981
# interval_17      0.637981
# interval_18      1.080438
# interval_19      0.799520
# interval_20      0.739513
# interval_21      0.528610
# interval_22      0.601971
# interval_23      0.041169
# interval_24      0.006776
# interval_25      0.006721
# interval_26      0.056472
# interval_27      0.278331
# interval_28      0.521057
# interval_29      0.647763
# interval_30      0.800779
# interval_31      0.750131
# interval_32      0.155761
# interval_33      0.308515
# interval_34      0.412022
# interval_35      0.528314
# interval_36      0.637040
# interval_37      0.951681
# interval_38      0.938143
# interval_39      1.025331
# interval_40      0.831719
# interval_41      0.382046
# interval_42      0.392111
# interval_43      0.712637
# interval_44      0.972310
# interval_45      1.000859
# interval_46      1.026235
# interval_47      1.008459
# interval_48      0.568359
# cluster_label    0.000000
# dtype: float64}, np.int64(4): {'mean': interval_1       0.198249
# interval_2       0.186982
# interval_3       0.173689
# interval_4       0.167728
# interval_5       0.159447
# interval_6       0.151373
# interval_7       0.147500
# interval_8       0.147415
# interval_9       0.137197
# interval_10      0.138965
# interval_11      0.139196
# interval_12      0.154436
# interval_13      0.171053
# interval_14      0.196099
# interval_15      0.190929
# interval_16      0.181968
# interval_17      0.179971
# interval_18      0.177064
# interval_19      0.177395
# interval_20      0.175762
# interval_21      0.172789
# interval_22      0.179254
# interval_23      0.174474
# interval_24      0.181285
# interval_25      0.177298
# interval_26      0.182734
# interval_27      0.183810
# interval_28      0.185188
# interval_29      0.190642
# interval_30      0.193856
# interval_31      0.197768
# interval_32      0.206089
# interval_33      0.225362
# interval_34      0.244752
# interval_35      0.263994
# interval_36      0.280835
# interval_37      0.291726
# interval_38      0.287503
# interval_39      0.280390
# interval_40      0.271691
# interval_41      0.271694
# interval_42      0.261061
# interval_43      0.259019
# interval_44      0.246455
# interval_45      0.240866
# interval_46      0.225746
# interval_47      0.213895
# interval_48      0.207853
# cluster_label    4.000000
# dtype: float64, 'min': interval_1       0.0
# interval_2       0.0
# interval_3       0.0
# interval_4       0.0
# interval_5       0.0
# interval_6       0.0
# interval_7       0.0
# interval_8       0.0
# interval_9       0.0
# interval_10      0.0
# interval_11      0.0
# interval_12      0.0
# interval_13      0.0
# interval_14      0.0
# interval_15      0.0
# interval_16      0.0
# interval_17      0.0
# interval_18      0.0
# interval_19      0.0
# interval_20      0.0
# interval_21      0.0
# interval_22      0.0
# interval_23      0.0
# interval_24      0.0
# interval_25      0.0
# interval_26      0.0
# interval_27      0.0
# interval_28      0.0
# interval_29      0.0
# interval_30      0.0
# interval_31      0.0
# interval_32      0.0
# interval_33      0.0
# interval_34      0.0
# interval_35      0.0
# interval_36      0.0
# interval_37      0.0
# interval_38      0.0
# interval_39      0.0
# interval_40      0.0
# interval_41      0.0
# interval_42      0.0
# interval_43      0.0
# interval_44      0.0
# interval_45      0.0
# interval_46      0.0
# interval_47      0.0
# interval_48      0.0
# cluster_label    4.0
# dtype: float64, 'max': interval_1       5.6750
# interval_2       5.6125
# interval_3       5.5875
# interval_4       5.6625
# interval_5       5.5375
# interval_6       4.0375
# interval_7       5.5375
# interval_8       5.6000
# interval_9       4.8875
# interval_10      4.2750
# interval_11      4.4750
# interval_12      4.8250
# interval_13      2.5625
# interval_14      2.7750
# interval_15      2.7375
# interval_16      2.9375
# interval_17      2.9500
# interval_18      3.6312
# interval_19      3.9750
# interval_20      3.9000
# interval_21      3.9125
# interval_22      5.5000
# interval_23      5.5750
# interval_24      5.3500
# interval_25      5.2000
# interval_26      5.0875
# interval_27      5.4125
# interval_28      5.3375
# interval_29      5.4375
# interval_30      5.5250
# interval_31      3.5500
# interval_32      3.5000
# interval_33      3.4562
# interval_34      5.1375
# interval_35      3.9625
# interval_36      3.5000
# interval_37      4.1250
# interval_38      5.5750
# interval_39      5.5625
# interval_40      5.5750
# interval_41      5.4750
# interval_42      5.5375
# interval_43      5.5375
# interval_44      5.6500
# interval_45      6.1875
# interval_46      5.7125
# interval_47      5.7125
# interval_48      5.7250
# cluster_label    4.0000
# dtype: float64, 'median': interval_1       0.11250
# interval_2       0.11000
# interval_3       0.10500
# interval_4       0.10150
# interval_5       0.10000
# interval_6       0.10000
# interval_7       0.10000
# interval_8       0.10000
# interval_9       0.10000
# interval_10      0.09700
# interval_11      0.10000
# interval_12      0.11050
# interval_13      0.12400
# interval_14      0.13120
# interval_15      0.13120
# interval_16      0.12500
# interval_17      0.12300
# interval_18      0.11300
# interval_19      0.11250
# interval_20      0.10620
# interval_21      0.10620
# interval_22      0.10450
# interval_23      0.10000
# interval_24      0.10800
# interval_25      0.10620
# interval_26      0.10550
# interval_27      0.10620
# interval_28      0.10150
# interval_29      0.10900
# interval_30      0.11100
# interval_31      0.11000
# interval_32      0.11500
# interval_33      0.12500
# interval_34      0.13750
# interval_35      0.14370
# interval_36      0.15800
# interval_37      0.17600
# interval_38      0.18900
# interval_39      0.19370
# interval_40      0.19370
# interval_41      0.18300
# interval_42      0.17850
# interval_43      0.16885
# interval_44      0.16200
# interval_45      0.14370
# interval_46      0.13000
# interval_47      0.12100
# interval_48      0.11800
# cluster_label    4.00000
# dtype: float64, 'std': interval_1       0.400374
# interval_2       0.366622
# interval_3       0.325994
# interval_4       0.324425
# interval_5       0.292215
# interval_6       0.253185
# interval_7       0.256478
# interval_8       0.255102
# interval_9       0.227292
# interval_10      0.209339
# interval_11      0.192896
# interval_12      0.197612
# interval_13      0.191362
# interval_14      0.239284
# interval_15      0.239059
# interval_16      0.222948
# interval_17      0.236815
# interval_18      0.242785
# interval_19      0.263491
# interval_20      0.256164
# interval_21      0.258408
# interval_22      0.295110
# interval_23      0.286792
# interval_24      0.282204
# interval_25      0.284131
# interval_26      0.303330
# interval_27      0.304690
# interval_28      0.313850
# interval_29      0.327365
# interval_30      0.327650
# interval_31      0.325082
# interval_32      0.343604
# interval_33      0.353504
# interval_34      0.373126
# interval_35      0.384886
# interval_36      0.376153
# interval_37      0.380434
# interval_38      0.367887
# interval_39      0.352049
# interval_40      0.342288
# interval_41      0.385158
# interval_42      0.386430
# interval_43      0.402736
# interval_44      0.407394
# interval_45      0.429781
# interval_46      0.418023
# interval_47      0.418425
# interval_48      0.415391
# cluster_label    0.000000
# dtype: float64}, np.int64(5): {'mean': interval_1       1.607169
# interval_2       1.400506
# interval_3       1.251179
# interval_4       1.015639
# interval_5       0.858150
# interval_6       0.865850
# interval_7       1.206498
# interval_8       1.285168
# interval_9       1.343070
# interval_10      0.888629
# interval_11      0.711149
# interval_12      0.637644
# interval_13      0.432427
# interval_14      0.461870
# interval_15      0.454227
# interval_16      0.462903
# interval_17      0.561613
# interval_18      0.592604
# interval_19      0.570289
# interval_20      0.642088
# interval_21      0.655211
# interval_22      0.657221
# interval_23      0.674886
# interval_24      0.684961
# interval_25      0.711095
# interval_26      0.695598
# interval_27      0.728762
# interval_28      0.716108
# interval_29      0.748956
# interval_30      0.767088
# interval_31      0.679279
# interval_32      0.669308
# interval_33      0.613627
# interval_34      0.638885
# interval_35      0.654536
# interval_36      0.663111
# interval_37      0.761771
# interval_38      0.901127
# interval_39      0.925612
# interval_40      0.879433
# interval_41      0.824886
# interval_42      0.796582
# interval_43      0.783098
# interval_44      0.615745
# interval_45      0.966107
# interval_46      0.882172
# interval_47      1.656962
# interval_48      1.687958
# cluster_label    5.000000
# dtype: float64, 'min': interval_1       0.1687
# interval_2       0.1562
# interval_3       0.1500
# interval_4       0.1437
# interval_5       0.1562
# interval_6       0.1437
# interval_7       0.1562
# interval_8       0.1250
# interval_9       0.0875
# interval_10      0.1250
# interval_11      0.0875
# interval_12      0.1437
# interval_13      0.0875
# interval_14      0.0000
# interval_15      0.0000
# interval_16      0.0000
# interval_17      0.0000
# interval_18      0.0000
# interval_19      0.0000
# interval_20      0.0000
# interval_21      0.0000
# interval_22      0.0000
# interval_23      0.0000
# interval_24      0.0000
# interval_25      0.0000
# interval_26      0.0000
# interval_27      0.0000
# interval_28      0.0000
# interval_29      0.0000
# interval_30      0.0000
# interval_31      0.0000
# interval_32      0.0000
# interval_33      0.0000
# interval_34      0.0000
# interval_35      0.0000
# interval_36      0.0000
# interval_37      0.0625
# interval_38      0.1750
# interval_39      0.1937
# interval_40      0.1875
# interval_41      0.1812
# interval_42      0.1875
# interval_43      0.1625
# interval_44      0.1687
# interval_45      0.1562
# interval_46      0.1687
# interval_47      0.1562
# interval_48      0.1562
# cluster_label    5.0000
# dtype: float64, 'max': interval_1        8.0625
# interval_2       12.7125
# interval_3       12.4000
# interval_4       12.3875
# interval_5        9.2000
# interval_6        4.2500
# interval_7       12.1000
# interval_8       12.1750
# interval_9       12.2000
# interval_10      12.2250
# interval_11      12.1875
# interval_12       2.1687
# interval_13       2.0000
# interval_14       1.7500
# interval_15       2.2875
# interval_16       2.3625
# interval_17       2.9750
# interval_18       2.8125
# interval_19       2.7875
# interval_20       4.0375
# interval_21       3.7250
# interval_22       4.4875
# interval_23       4.7125
# interval_24       4.8500
# interval_25       5.1375
# interval_26       4.7250
# interval_27       5.9375
# interval_28       4.7250
# interval_29       4.0250
# interval_30      12.4500
# interval_31      12.0250
# interval_32       8.9125
# interval_33       4.3625
# interval_34       5.5125
# interval_35       4.9125
# interval_36       3.7875
# interval_37       3.9875
# interval_38       8.8625
# interval_39      12.3000
# interval_40      12.2250
# interval_41       5.6375
# interval_42       8.6625
# interval_43      12.9500
# interval_44       4.0312
# interval_45       4.7250
# interval_46       4.5875
# interval_47       6.9625
# interval_48       6.9125
# cluster_label     5.0000
# dtype: float64, 'median': interval_1       0.5125
# interval_2       0.5000
# interval_3       0.4875
# interval_4       0.4625
# interval_5       0.2875
# interval_6       0.4500
# interval_7       0.4875
# interval_8       0.4625
# interval_9       0.5000
# interval_10      0.4625
# interval_11      0.2812
# interval_12      0.4875
# interval_13      0.3750
# interval_14      0.3875
# interval_15      0.3000
# interval_16      0.2625
# interval_17      0.2625
# interval_18      0.2437
# interval_19      0.2312
# interval_20      0.2562
# interval_21      0.2750
# interval_22      0.2687
# interval_23      0.2500
# interval_24      0.2562
# interval_25      0.2500
# interval_26      0.2062
# interval_27      0.3062
# interval_28      0.3687
# interval_29      0.5750
# interval_30      0.4750
# interval_31      0.4750
# interval_32      0.4500
# interval_33      0.4562
# interval_34      0.4375
# interval_35      0.4750
# interval_36      0.5062
# interval_37      0.5687
# interval_38      0.5875
# interval_39      0.5750
# interval_40      0.5875
# interval_41      0.5500
# interval_42      0.5375
# interval_43      0.5375
# interval_44      0.4625
# interval_45      0.4875
# interval_46      0.4000
# interval_47      0.5750
# interval_48      0.5250
# cluster_label    5.0000
# dtype: float64, 'std': interval_1       2.043701
# interval_2       1.976531
# interval_3       1.858380
# interval_4       1.673910
# interval_5       1.419497
# interval_6       1.128742
# interval_7       1.968071
# interval_8       1.987557
# interval_9       2.037289
# interval_10      1.459124
# interval_11      1.387970
# interval_12      0.460725
# interval_13      0.252944
# interval_14      0.359242
# interval_15      0.440543
# interval_16      0.491338
# interval_17      0.638266
# interval_18      0.698826
# interval_19      0.687031
# interval_20      0.772546
# interval_21      0.803804
# interval_22      0.860878
# interval_23      0.881348
# interval_24      0.871916
# interval_25      0.891306
# interval_26      0.929604
# interval_27      0.972583
# interval_28      0.873099
# interval_29      0.852452
# interval_30      1.323014
# interval_31      1.241147
# interval_32      1.063761
# interval_33      0.831430
# interval_34      0.886177
# interval_35      0.765346
# interval_36      0.644542
# interval_37      0.665480
# interval_38      0.988514
# interval_39      1.240517
# interval_40      1.223464
# interval_41      0.844200
# interval_42      1.039914
# interval_43      1.304234
# interval_44      0.650305
# interval_45      1.260395
# interval_46      1.219674
# interval_47      1.949371
# interval_48      2.058287
# cluster_label    0.000000
# dtype: float64}}
# Cluster 1 Profile:
# Size: 376 samples
# Distinguished by (percentage above average):
# Highest by consumption:
# - interval_4: 91.4%
# - interval_3: 90.7%
# - interval_2: 89.9%
#
# Lowest by consumption:
# - interval_25: -44.6%
# - interval_24: -49.4%
# - cluster_label: -65.5%
#
#
# Cluster 4 Profile:
# Size: 2344 samples
# Distinguished by (percentage above average):
# Highest by consumption:
# - cluster_label: 37.9%
# - interval_33: -27.6%
# - interval_34: -27.7%
#
# Lowest by consumption:
# - interval_1: -42.3%
# - interval_47: -42.4%
# - interval_9: -45.8%
#
#
# Cluster 0 Profile:
# Size: 718 samples
# Distinguished by (percentage above average):
# Highest by consumption:
# - interval_17: 111.2%
# - interval_18: 108.5%
# - interval_19: 108.4%
#
# Lowest by consumption:
# - interval_2: 33.2%
# - interval_4: 33.0%
# - cluster_label: -100.0%
#
#
# Cluster 5 Profile:
# Size: 121 samples
# Distinguished by (percentage above average):
# Highest by consumption:
# - interval_9: 430.7%
# - interval_8: 413.0%
# - interval_7: 383.5%
#
# Lowest by consumption:
# - interval_16: 61.9%
# - interval_15: 56.5%
# - interval_14: 55.3%
#
#
# Cluster 2 Profile:
# Size: 40 samples
# Distinguished by (percentage above average):
# Highest by consumption:
# - interval_13: 207.5%
# - interval_14: 107.9%
# - interval_15: 94.1%
#
# Lowest by consumption:
# - interval_48: -85.8%
# - interval_45: -86.1%
# - interval_47: -87.0%
#
#
# Cluster 3 Profile:
# Size: 44 samples
# Distinguished by (percentage above average):
# Highest by consumption:
# - interval_15: 344.9%
# - interval_16: 253.5%
# - interval_11: 157.0%
#
# Lowest by consumption:
# - interval_26: -95.6%
# - interval_24: -98.0%
# - interval_25: -98.1%

# %% [markdown]
# #### **4. Normalization**

# %%
feature_scaler = FeatureScaler()

# Fit the scaler on the training data
X_train_scaled = feature_scaler.fit_transform(X_train_with_clusters)
X_test_scaled = feature_scaler.transform(X_test_with_clusters)
# Out:
# Normal features (StandardScaler): []
# Non-normal features (MinMaxScaler): ['interval_1', 'interval_2', 'interval_3', 'interval_4', 'interval_5', 'interval_6', 'interval_7', 'interval_8', 'interval_9', 'interval_10', 'interval_11', 'interval_12', 'interval_13', 'interval_14', 'interval_15', 'interval_16', 'interval_17', 'interval_18', 'interval_19', 'interval_20', 'interval_21', 'interval_22', 'interval_23', 'interval_24', 'interval_25', 'interval_26', 'interval_27', 'interval_28', 'interval_29', 'interval_30', 'interval_31', 'interval_32', 'interval_33', 'interval_34', 'interval_35', 'interval_36', 'interval_37', 'interval_38', 'interval_39', 'interval_40', 'interval_41', 'interval_42', 'interval_43', 'interval_44', 'interval_45', 'interval_46', 'interval_47', 'interval_48', 'cluster_label']

# %%
X_train_scaled
# Out:
#       interval_1  interval_2  interval_3  interval_4  interval_5  interval_6  \
# 0       0.124625    0.081613    0.064008    0.005045    0.006109    0.007485
# 1       0.003748    0.007866    0.003024    0.005546    0.006793    0.007485
# 2       0.011892    0.005742    0.010484    0.012513    0.014022    0.012455
# 3       0.032072    0.009204    0.006774    0.007750    0.011848    0.008623
# 4       0.023267    0.013270    0.013605    0.009082    0.012228    0.014216
# ...          ...         ...         ...         ...         ...         ...
# 3638    0.015976    0.011170    0.009839    0.010817    0.015326    0.015329
# 3639    0.083604    0.013845    0.008306    0.008315    0.009565    0.010898
# 3640    0.007928    0.004641    0.004355    0.002664    0.003478    0.003832
# 3641    0.015015    0.008850    0.008565    0.010091    0.011543    0.014216
# 3642    0.111111    0.030482    0.021169    0.020182    0.025815    0.026946
#
#       interval_7  interval_8  interval_9  interval_10  ...  interval_40  \
# 0       0.004645    0.004616    0.005123     0.004597  ...     0.084352
# 1       0.004645    0.005133    0.011270     0.008687  ...     0.015845
# 2       0.009008    0.010021    0.008197     0.007853  ...     0.018896
# 3       0.008017    0.007228    0.006803     0.008098  ...     0.123926
# 4       0.008777    0.009240    0.008197     0.007665  ...     0.071575
# ...          ...         ...         ...          ...  ...          ...
# 3638    0.010744    0.011663    0.010984     0.009816  ...     0.018896
# 3639    0.006529    0.007474    0.018934     0.009898  ...     0.033947
# 3640    0.002645    0.002793    0.002295     0.010225  ...     0.018732
# 3641    0.009298    0.009240    0.009730     0.008687  ...     0.049080
# 3642    0.019628    0.020534    0.017418     0.021472  ...     0.027607
#
#       interval_41  interval_42  interval_43  interval_44  interval_45  \
# 0        0.133272     0.120485     0.078664     0.140893     0.144852
# 1        0.020689     0.043290     0.011583     0.013746     0.008726
# 2        0.017086     0.012583     0.012124     0.015258     0.013264
# 3        0.181589     0.013968     0.007490     0.014433     0.011728
# 4        0.034768     0.023804     0.019305     0.017182     0.039260
# ...           ...          ...          ...          ...          ...
# 3638     0.032318     0.025397     0.016525     0.019381     0.019127
# 3639     0.038808     0.024242     0.025174     0.037526     0.030017
# 3640     0.010066     0.026205     0.004865     0.013746     0.008796
# 3641     0.067046     0.058436     0.040054     0.064426     0.066318
# 3642     0.069536     0.115440     0.027027     0.048110     0.111693
#
#       interval_46  interval_47  interval_48  cluster_label
# 0        0.138047     0.124066     0.121636            0.2
# 1        0.006734     0.006720     0.007463            0.8
# 2        0.018182     0.014948     0.010985            0.8
# 3        0.013872     0.011360     0.010746            0.0
# 4        0.054707     0.037369     0.035821            0.0
# ...           ...          ...          ...            ...
# 3638     0.016162     0.016741     0.016358            0.8
# 3639     0.120135     0.024275     0.017552            0.0
# 3640     0.006465     0.005620     0.005731            0.8
# 3641     0.059758     0.054553     0.054472            0.0
# 3642     0.057239     0.029895     0.035821            0.8
#
# [3643 rows x 49 columns]

# %%
# X_train_scaled = X_train_scaled.drop(columns=['cluster_label'])
# X_test_scaled = X_test_scaled.drop(columns=['cluster_label'])

# %% [markdown]
# ## **Modelling**
#
# Menggunakan 2 pendekatan model yaitu, Logistic Regression dan K-Nearest Neighbors.

# %% [markdown]
# ### **Proses Pelatihan**

# %%
import numpy as np


# Define Kelas untuk LogReg
class LogisticRegression():
    # Init konstruktor dengan params learning rate dan jumlah iterasi
    def __init__(self, lr=0.001, n_iters=200):
        self.lr = lr
        self.n_iters = n_iters
        self.weights = None
        self.bias = None

    # Define fungsi sigmoid
    def sigmoid(self, x):
        # Merubah input menjadi probabilitas di range (0,1)
        return 1/(1+np.exp(-x))

    # fit dengan data train 
    def fit(self, X, y):
        n_samples, n_features = X.shape
        self.weights = np.zeros(n_features)
        self.bias = 0

        # Loop untuk update parameter sebanyak n_iters
        for _ in range(self.n_iters):
            # hitung linear prediction
            linear_pred = np.dot(X, self.weights) + self.bias
            # masukkan ke sigmoid
            predictions = self.sigmoid(linear_pred)

           # cari gradien untuk weight dan bias (optimization)
            dw = (1/n_samples) * np.dot(X.T, (predictions - y))
            db = (1/n_samples) * np.sum(predictions-y)
            
            # update weight dan bias
            self.weights = self.weights - self.lr*dw
            self.bias = self.bias - self.lr*db

        return self

    # prediksi data test
    def predict(self, X):
        linear_pred = np.dot(X, self.weights) + self.bias
        y_pred = self.sigmoid(linear_pred)
        # jika probabilitas > 0.5, maka kelas 1, jika tidak kelas 0
        class_pred = [0 if y<=0.5 else 1 for y in y_pred]
        return class_pred
    


class KNearestNeighbors:
    def __init__(self, k=3):
        """
        Initialize the KNN classifier.
        
        Parameters:
        - k (int): Number of neighbors to consider.
        """
        self.k = k

    def fit(self, X, y):
        """
        Fit the model to the training data.
        
        Parameters:
        - X (np.ndarray): Feature matrix for training data.
        - y (np.ndarray): Labels for training data.
        """
        self.X_train = X
        self.y_train = y

    def predict(self, X):
        """
        Predict the class labels for the provided data.
        
        Parameters:
        - X (np.ndarray): Feature matrix for test data.
        
        Returns:
        - np.ndarray: Predicted class labels.
        """
        predictions = [self._predict_single(x) for x in X]
        return np.array(predictions)

    def _predict_single(self, x):
        """
        Predict the class label for a single data point.
        
        Parameters:
        - x (np.ndarray): A single test data point.
        
        Returns:
        - int: Predicted class label.
        """
        # Compute distances between x and all training samples
        distances = [self._euclidean_distance(x, x_train) for x_train in self.X_train]
        
        # Get indices of k nearest neighbors
        k_indices = np.argsort(distances)[:self.k]
        
        # Extract the labels of the k nearest neighbors
        k_nearest_labels = [self.y_train[i] for i in k_indices]
        
        # Determine the most common label among the k neighbors
        most_common = Counter(k_nearest_labels).most_common(1)
        return most_common[0][0]

    def _euclidean_distance(self, x1, x2):
        """
        Compute the Euclidean distance between two points.
        
        Parameters:
        - x1 (np.ndarray): First data point.
        - x2 (np.ndarray): Second data point.
        
        Returns:
        - float: Euclidean distance.
        """
        return np.sqrt(np.sum((x1 - x2) ** 2))
    
import numpy as np
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

class EnsembleVoter:
    def __init__(self, model1, model2, prefer_model2=True):
        """
        Initialize the ensemble voter with two models.
        Args:
            model1: First model (LogisticRegression in this case)
            model2: Second model (KNN in this case)
            prefer_model2: If True, use model2's prediction when models disagree
        """
        self.model1 = model1
        self.model2 = model2
        self.prefer_model2 = prefer_model2
    
    def fit(self, X_train, y_train):
        """
        Fit both models with the training data
        """
        # Handle different input types (numpy array vs pandas DataFrame)
        X_train_values = X_train.values if hasattr(X_train, 'values') else X_train
        y_train_values = y_train.values.ravel() if hasattr(y_train, 'values') else y_train
        
        # Fit both models
        self.model1.fit(X_train, y_train_values)
        self.model2.fit(X_train_values, y_train_values)
        
        return self
    
    def predict(self, X_test):
        """
        Make predictions using both models and combine them using hard voting
        """
        # Handle different input types
        X_test_values = X_test.values if hasattr(X_test, 'values') else X_test
        
        # Get predictions from both models
        pred1 = self.model1.predict(X_test)
        pred2 = self.model2.predict(X_test_values)
        
        # Initialize final predictions array
        final_predictions = np.zeros_like(pred1)
        
        # Implement hard voting with preference for model2 (KNN) when there's disagreement
        for i in range(len(pred1)):
            if pred1[i] == pred2[i]:
                final_predictions[i] = pred1[i]
            else:
                # When models disagree, use model2's prediction if prefer_model2 is True
                final_predictions[i] = pred2[i] if self.prefer_model2 else pred1[i]
        
        return final_predictions

# %%
# Training with Logistic Regression
log_reg = LogisticRegression(lr=0.01, n_iters=1000)

# Fit the model to training data
log_reg.fit(X_train_scaled, y_train.values.ravel())

# Predict on the test data
y_pred_logreg = log_reg.predict(X_test_scaled)

# %%
# Instantiate the KNN model
knn = KNearestNeighbors(k=5)

# Fit the model to the training data (including cluster_label)
knn.fit(X_train_scaled.values, y_train.values.ravel())

# Predict on the test data (including cluster_label)
y_pred_knn = knn.predict(X_test_scaled.values)

# %%
# Create the ensemble voter
ensemble = EnsembleVoter(log_reg, knn, prefer_model2=True)

# Fit the ensemble
ensemble.fit(X_train_scaled, y_train)

# Make predictions
y_pred_ensemble = ensemble.predict(X_test_scaled)

# %% [markdown]
# ### **Proses Pengujian**

# %%
def plot_confusion_matrix(y_true, y_pred, class_names):
    """
    Plot a confusion matrix as a heatmap with counts and percentages.
    Args:
        y_true: Array-like of true labels.
        y_pred: Array-like of predicted labels.
        class_names: List of class names.
    """
    # Compute confusion matrix
    cm = confusion_matrix(y_true, y_pred)
    cm_percentage = cm / cm.sum(axis=1, keepdims=True) * 100  # Calculate percentages

    # Combine counts and percentages into one display
    cm_display = np.empty_like(cm, dtype=object)
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            cm_display[i, j] = f"{cm[i, j]}\n({cm_percentage[i, j]:.1f}%)"

    # Create a heatmap
    plt.figure(figsize=(10, 8))
    sns.heatmap(cm, annot=cm_display, fmt="", cmap="Blues", xticklabels=class_names, yticklabels=class_names, cbar=False)
    plt.title("Confusion Matrix with Counts and Percentages", fontsize=16)
    plt.xlabel("Predicted Labels", fontsize=14)
    plt.ylabel("True Labels", fontsize=14)
    plt.xticks(fontsize=12)
    plt.yticks(fontsize=12)
    plt.show()

# %%
# Define class names (adjust based on your dataset)
class_names = ['Class 0', 'Class 1']

# %%
# Evaluate the model
print("Logistic Regression Model Evaluation:")
print(f"Accuracy: {accuracy_score(y_test, y_pred_logreg):.4f}")
print(f"Precision: {precision_score(y_test, y_pred_logreg):.4f}")
print(f"Recall: {recall_score(y_test, y_pred_logreg):.4f}")
print(f"F1-Score: {f1_score(y_test, y_pred_logreg):.4f}")

# Detailed Classification Report
print("\nClassification Report:")
print(classification_report(y_test, y_pred_logreg))
# Out:
# Logistic Regression Model Evaluation:
# Accuracy: 0.5877
# Precision: 0.6522
# Recall: 0.3713
# F1-Score: 0.4732
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.56      0.80      0.66       203
#            1       0.65      0.37      0.47       202
#
#     accuracy                           0.59       405
#    macro avg       0.61      0.59      0.57       405
# weighted avg       0.61      0.59      0.57       405

# %%
# Call the function to plot
plot_confusion_matrix(y_test, y_pred_logreg, class_names)

# %%
# Evaluate the model
print("K-Nearest Neighbors Model Evaluation:")
print(f"Accuracy: {accuracy_score(y_test, y_pred_knn):.4f}")
print(f"Precision: {precision_score(y_test, y_pred_knn):.4f}")
print(f"Recall: {recall_score(y_test, y_pred_knn):.4f}")
print(f"F1-Score: {f1_score(y_test, y_pred_knn):.4f}")

# Detailed Classification Report
print("\nClassification Report:")
print(classification_report(y_test, y_pred_knn))
# Out:
# K-Nearest Neighbors Model Evaluation:
# Accuracy: 0.8296
# Precision: 0.8595
# Recall: 0.7871
# F1-Score: 0.8217
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.80      0.87      0.84       203
#            1       0.86      0.79      0.82       202
#
#     accuracy                           0.83       405
#    macro avg       0.83      0.83      0.83       405
# weighted avg       0.83      0.83      0.83       405

# %%
# Call the function to plot
plot_confusion_matrix(y_test, y_pred_knn, class_names)

# %%
# Evaluate the model
print("Ensemble Model Evaluation:")
print(f"Accuracy: {accuracy_score(y_test, y_pred_ensemble):.4f}")
print(f"Precision: {precision_score(y_test, y_pred_ensemble):.4f}")
print(f"Recall: {recall_score(y_test, y_pred_ensemble):.4f}")
print(f"F1-Score: {f1_score(y_test, y_pred_ensemble):.4f}")

# Detailed Classification Report
print("\nClassification Report:")
print(classification_report(y_test, y_pred_ensemble))
# Out:
# Ensemble Model Evaluation:
# Accuracy: 0.8296
# Precision: 0.8595
# Recall: 0.7871
# F1-Score: 0.8217
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.80      0.87      0.84       203
#            1       0.86      0.79      0.82       202
#
#     accuracy                           0.83       405
#    macro avg       0.83      0.83      0.83       405
# weighted avg       0.83      0.83      0.83       405

# %%
plot_confusion_matrix(y_test, y_pred_ensemble, class_names)

# %% [markdown]
# ## **Model Evaluation**

# %% [markdown]
# ### **Mengukur Performansi Model**

# %% [markdown]
# ### **Menilai Apakah Proses Sudah Maksimal (Room for Improvement)**
